# %%
import boto3

rek = boto3.client("rekognition")

# %%
response = rek.get_label_detection(JobId="dfb24c69b764002122cf07453ec2a0c468e94bfb9094e903efb50ad2ada94ce6")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In [38], line 1
# ----> 1 response = rek.get_label_detection(JobId="dfb24c69b764002122cf07453ec2a0c468e94bfb9094e903efb50ad2ada94ce6")
#
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/botocore/client.py:507, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     503     raise TypeError(
#     504         f"{py_operation_name}() only accepts keyword arguments."
#     505     )
#     506 # The "self" in this scope is referring to the BaseClient.
# --> 507 return self._make_api_call(operation_name, kwargs)
#
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/botocore/client.py:926, in BaseClient._make_api_call(self, operation_name, api_params)
#     924 else:
#     925     apply_request_checksum(request_dict)
# ...

# %%
response

# %%
event = {}

event["LabelDetectionComplete"] = False
event["LabelDetectionData"] = response

# %%
event["LabelDetectionComplete"]

# %%
event = {
  "bucket": "video-ingest-200608916304-us-west-2",
  "key": "TheAstronautOfficialTeaser34.mp4",
  "job_id": "b2c15d85a37c54ffd5e1d618579f0f06eae49da29287511c3808c8e5085d9ef7",
  "LabelDetectionComplete": "SUCCEEDED",
  "LabelDetectionData": {
    "JobStatus": "SUCCEEDED",
    "VideoMetadata": {
      "Codec": "h264",
      "DurationMillis": 38000,
      "Format": "QuickTime / MOV",
      "FrameRate": 24,
      "FrameHeight": 720,
      "FrameWidth": 1280,
      "ColorRange": "LIMITED"
    },
    "Labels": [
      {
        "Timestamp": 0,
        "Label": {
          "Name": "Apparel",
          "Confidence": 55.38291549682617,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 0,
        "Label": {
          "Name": "Arrow",
          "Confidence": 50.12788391113281,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 0,
        "Label": {
          "Name": "Clothing",
          "Confidence": 55.38291549682617,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 0,
        "Label": {
          "Name": "Face",
          "Confidence": 51.44035720825195,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 0,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 52.31382369995117,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 0,
        "Label": {
          "Name": "Page",
          "Confidence": 53.37156295776367,
          "Instances": [],
          "Parents": [
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 0,
        "Label": {
          "Name": "Symbol",
          "Confidence": 50.12788391113281,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 0,
        "Label": {
          "Name": "Text",
          "Confidence": 54.760807037353516,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 0,
        "Label": {
          "Name": "Texture",
          "Confidence": 97.13557434082031,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 0,
        "Label": {
          "Name": "White",
          "Confidence": 97.13557434082031,
          "Instances": [],
          "Parents": [
            {
              "Name": "Texture"
            }
          ]
        }
      },
      {
        "Timestamp": 0,
        "Label": {
          "Name": "White Board",
          "Confidence": 63.33339309692383,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 500,
        "Label": {
          "Name": "Apparel",
          "Confidence": 58.57859802246094,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 500,
        "Label": {
          "Name": "Clothing",
          "Confidence": 58.57859802246094,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 500,
        "Label": {
          "Name": "Face",
          "Confidence": 56.79867935180664,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 500,
        "Label": {
          "Name": "Text",
          "Confidence": 61.01749038696289,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 500,
        "Label": {
          "Name": "Texture",
          "Confidence": 93.8719253540039,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 500,
        "Label": {
          "Name": "White",
          "Confidence": 93.8719253540039,
          "Instances": [],
          "Parents": [
            {
              "Name": "Texture"
            }
          ]
        }
      },
      {
        "Timestamp": 500,
        "Label": {
          "Name": "White Board",
          "Confidence": 59.60886764526367,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 999,
        "Label": {
          "Name": "Alphabet",
          "Confidence": 51.973419189453125,
          "Instances": [],
          "Parents": [
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 999,
        "Label": {
          "Name": "Apparel",
          "Confidence": 64.81015014648438,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 999,
        "Label": {
          "Name": "Clothing",
          "Confidence": 64.81015014648438,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 999,
        "Label": {
          "Name": "Face",
          "Confidence": 70.83307647705078,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 999,
        "Label": {
          "Name": "Symbol",
          "Confidence": 51.25776672363281,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 999,
        "Label": {
          "Name": "Text",
          "Confidence": 78.73695373535156,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 999,
        "Label": {
          "Name": "Texture",
          "Confidence": 79.09803009033203,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 999,
        "Label": {
          "Name": "White",
          "Confidence": 79.09803009033203,
          "Instances": [],
          "Parents": [
            {
              "Name": "Texture"
            }
          ]
        }
      },
      {
        "Timestamp": 1500,
        "Label": {
          "Name": "Alphabet",
          "Confidence": 55.7641716003418,
          "Instances": [],
          "Parents": [
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 1500,
        "Label": {
          "Name": "Apparel",
          "Confidence": 56.6563606262207,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 1500,
        "Label": {
          "Name": "Clothing",
          "Confidence": 56.6563606262207,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 1500,
        "Label": {
          "Name": "Face",
          "Confidence": 66.88259887695312,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 1500,
        "Label": {
          "Name": "Logo",
          "Confidence": 55.18025207519531,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 1500,
        "Label": {
          "Name": "Symbol",
          "Confidence": 59.15155029296875,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 1500,
        "Label": {
          "Name": "Text",
          "Confidence": 81.1104507446289,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 1500,
        "Label": {
          "Name": "Texture",
          "Confidence": 61.67165756225586,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 1500,
        "Label": {
          "Name": "Trademark",
          "Confidence": 55.18025207519531,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 1500,
        "Label": {
          "Name": "White",
          "Confidence": 61.67165756225586,
          "Instances": [],
          "Parents": [
            {
              "Name": "Texture"
            }
          ]
        }
      },
      {
        "Timestamp": 2000,
        "Label": {
          "Name": "Alphabet",
          "Confidence": 52.6462516784668,
          "Instances": [],
          "Parents": [
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 2000,
        "Label": {
          "Name": "Apparel",
          "Confidence": 52.20912170410156,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 2000,
        "Label": {
          "Name": "Clothing",
          "Confidence": 52.20912170410156,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 2000,
        "Label": {
          "Name": "Logo",
          "Confidence": 61.150657653808594,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 2000,
        "Label": {
          "Name": "Symbol",
          "Confidence": 63.812843322753906,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 2000,
        "Label": {
          "Name": "Text",
          "Confidence": 81.04238891601562,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 2000,
        "Label": {
          "Name": "Texture",
          "Confidence": 60.352027893066406,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 2000,
        "Label": {
          "Name": "Trademark",
          "Confidence": 61.150657653808594,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 2000,
        "Label": {
          "Name": "White",
          "Confidence": 60.352027893066406,
          "Instances": [],
          "Parents": [
            {
              "Name": "Texture"
            }
          ]
        }
      },
      {
        "Timestamp": 2500,
        "Label": {
          "Name": "Apparel",
          "Confidence": 54.182090759277344,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 2500,
        "Label": {
          "Name": "Clothing",
          "Confidence": 54.182090759277344,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 2500,
        "Label": {
          "Name": "Logo",
          "Confidence": 65.32957458496094,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 2500,
        "Label": {
          "Name": "Symbol",
          "Confidence": 68.7479019165039,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 2500,
        "Label": {
          "Name": "Text",
          "Confidence": 80.60690307617188,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 2500,
        "Label": {
          "Name": "Texture",
          "Confidence": 64.9373550415039,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 2500,
        "Label": {
          "Name": "Trademark",
          "Confidence": 65.32957458496094,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 2500,
        "Label": {
          "Name": "White",
          "Confidence": 64.9373550415039,
          "Instances": [],
          "Parents": [
            {
              "Name": "Texture"
            }
          ]
        }
      },
      {
        "Timestamp": 2999,
        "Label": {
          "Name": "Apparel",
          "Confidence": 61.450225830078125,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 2999,
        "Label": {
          "Name": "Clothing",
          "Confidence": 61.450225830078125,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 2999,
        "Label": {
          "Name": "Face",
          "Confidence": 67.60713958740234,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 2999,
        "Label": {
          "Name": "Logo",
          "Confidence": 78.08927154541016,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 2999,
        "Label": {
          "Name": "Symbol",
          "Confidence": 79.07499694824219,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 2999,
        "Label": {
          "Name": "Text",
          "Confidence": 86.03694915771484,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 2999,
        "Label": {
          "Name": "Texture",
          "Confidence": 59.14720916748047,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 2999,
        "Label": {
          "Name": "Trademark",
          "Confidence": 78.08927154541016,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 2999,
        "Label": {
          "Name": "White",
          "Confidence": 59.14720916748047,
          "Instances": [],
          "Parents": [
            {
              "Name": "Texture"
            }
          ]
        }
      },
      {
        "Timestamp": 3499,
        "Label": {
          "Name": "Apparel",
          "Confidence": 64.39961242675781,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 3499,
        "Label": {
          "Name": "Clothing",
          "Confidence": 64.39961242675781,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 3499,
        "Label": {
          "Name": "Face",
          "Confidence": 84.5618896484375,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 3499,
        "Label": {
          "Name": "Logo",
          "Confidence": 82.46186065673828,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 3499,
        "Label": {
          "Name": "Symbol",
          "Confidence": 82.46186065673828,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 3499,
        "Label": {
          "Name": "Text",
          "Confidence": 88.3987045288086,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 3499,
        "Label": {
          "Name": "Texture",
          "Confidence": 56.20610046386719,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 3499,
        "Label": {
          "Name": "Trademark",
          "Confidence": 82.46186065673828,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 3499,
        "Label": {
          "Name": "White",
          "Confidence": 56.20610046386719,
          "Instances": [],
          "Parents": [
            {
              "Name": "Texture"
            }
          ]
        }
      },
      {
        "Timestamp": 3499,
        "Label": {
          "Name": "Word",
          "Confidence": 55.70151901245117,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 3999,
        "Label": {
          "Name": "Apparel",
          "Confidence": 64.67139434814453,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 3999,
        "Label": {
          "Name": "Clothing",
          "Confidence": 64.67139434814453,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 3999,
        "Label": {
          "Name": "Face",
          "Confidence": 84.68604278564453,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 3999,
        "Label": {
          "Name": "Logo",
          "Confidence": 82.4558334350586,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 3999,
        "Label": {
          "Name": "Symbol",
          "Confidence": 82.4558334350586,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 3999,
        "Label": {
          "Name": "Text",
          "Confidence": 88.49559783935547,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 3999,
        "Label": {
          "Name": "Texture",
          "Confidence": 56.08692932128906,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 3999,
        "Label": {
          "Name": "Trademark",
          "Confidence": 82.4558334350586,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 3999,
        "Label": {
          "Name": "White",
          "Confidence": 56.08692932128906,
          "Instances": [],
          "Parents": [
            {
              "Name": "Texture"
            }
          ]
        }
      },
      {
        "Timestamp": 3999,
        "Label": {
          "Name": "Word",
          "Confidence": 55.3798713684082,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 4499,
        "Label": {
          "Name": "Apparel",
          "Confidence": 70.17617797851562,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 4499,
        "Label": {
          "Name": "Clothing",
          "Confidence": 70.17617797851562,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 4499,
        "Label": {
          "Name": "Face",
          "Confidence": 67.9891357421875,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 4499,
        "Label": {
          "Name": "Logo",
          "Confidence": 66.13223266601562,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 4499,
        "Label": {
          "Name": "Symbol",
          "Confidence": 75.5604476928711,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 4499,
        "Label": {
          "Name": "Text",
          "Confidence": 71.07557678222656,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 4499,
        "Label": {
          "Name": "Trademark",
          "Confidence": 66.13223266601562,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 5000,
        "Label": {
          "Name": "Apparel",
          "Confidence": 84.48210144042969,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 5000,
        "Label": {
          "Name": "Clothing",
          "Confidence": 84.48210144042969,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 5000,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 50.87546920776367,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 5000,
        "Label": {
          "Name": "Helmet",
          "Confidence": 71.73938751220703,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.08965706825256348,
                "Height": 0.12741394340991974,
                "Left": 0.34449997544288635,
                "Top": 0.6956592798233032
              },
              "Confidence": 92.5274887084961
            }
          ],
          "Parents": [
            {
              "Name": "Clothing"
            }
          ]
        }
      },
      {
        "Timestamp": 5000,
        "Label": {
          "Name": "Human",
          "Confidence": 78.58182525634766,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 5000,
        "Label": {
          "Name": "Nature",
          "Confidence": 70.28790283203125,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 5000,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 70.87590789794922,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 5000,
        "Label": {
          "Name": "Person",
          "Confidence": 78.58182525634766,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.29541224241256714,
                "Height": 0.5858514904975891,
                "Left": 0.4517359733581543,
                "Top": 0.23308448493480682
              },
              "Confidence": 97.8653564453125
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 5000,
        "Label": {
          "Name": "Photo",
          "Confidence": 50.73271179199219,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 5000,
        "Label": {
          "Name": "Photography",
          "Confidence": 50.73271179199219,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 5000,
        "Label": {
          "Name": "Sand",
          "Confidence": 52.375022888183594,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 5000,
        "Label": {
          "Name": "Soil",
          "Confidence": 79.3081283569336,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 5000,
        "Label": {
          "Name": "Symbol",
          "Confidence": 54.020328521728516,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 5500,
        "Label": {
          "Name": "Apparel",
          "Confidence": 82.97183990478516,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 5500,
        "Label": {
          "Name": "Clothing",
          "Confidence": 82.97183990478516,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 5500,
        "Label": {
          "Name": "Desert",
          "Confidence": 60.41943359375,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 5500,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 50.34775161743164,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 5500,
        "Label": {
          "Name": "Helmet",
          "Confidence": 82.97183990478516,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.09110520035028458,
                "Height": 0.12119907885789871,
                "Left": 0.34379249811172485,
                "Top": 0.7031320929527283
              },
              "Confidence": 79.51536560058594
            }
          ],
          "Parents": [
            {
              "Name": "Clothing"
            }
          ]
        }
      },
      {
        "Timestamp": 5500,
        "Label": {
          "Name": "Human",
          "Confidence": 97.80249786376953,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 5500,
        "Label": {
          "Name": "Nature",
          "Confidence": 89.08209991455078,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 5500,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 90.71302795410156,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 5500,
        "Label": {
          "Name": "Person",
          "Confidence": 97.80249786376953,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.29629021883010864,
                "Height": 0.5858055949211121,
                "Left": 0.4503886103630066,
                "Top": 0.23751068115234375
              },
              "Confidence": 97.82966613769531
            },
            {
              "BoundingBox": {
                "Width": 0.08929087966680527,
                "Height": 0.12456274777650833,
                "Left": 0.34137505292892456,
                "Top": 0.6987487077713013
              },
              "Confidence": 55.22294998168945
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 5500,
        "Label": {
          "Name": "Photo",
          "Confidence": 64.78948974609375,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 5500,
        "Label": {
          "Name": "Photography",
          "Confidence": 64.78948974609375,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 5500,
        "Label": {
          "Name": "Sand",
          "Confidence": 70.48981475830078,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 5500,
        "Label": {
          "Name": "Sitting",
          "Confidence": 58.24611282348633,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 5500,
        "Label": {
          "Name": "Soil",
          "Confidence": 96.62873840332031,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 6000,
        "Label": {
          "Name": "Apparel",
          "Confidence": 82.52288818359375,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 6000,
        "Label": {
          "Name": "Clothing",
          "Confidence": 82.52288818359375,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 6000,
        "Label": {
          "Name": "Desert",
          "Confidence": 52.646270751953125,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 6000,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 52.49251937866211,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 6000,
        "Label": {
          "Name": "Helmet",
          "Confidence": 82.52288818359375,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.09329243004322052,
                "Height": 0.1212993636727333,
                "Left": 0.3389497697353363,
                "Top": 0.7063030004501343
              },
              "Confidence": 84.05148315429688
            }
          ],
          "Parents": [
            {
              "Name": "Clothing"
            }
          ]
        }
      },
      {
        "Timestamp": 6000,
        "Label": {
          "Name": "Human",
          "Confidence": 97.59095764160156,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 6000,
        "Label": {
          "Name": "Nature",
          "Confidence": 86.84158325195312,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 6000,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 90.79402923583984,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 6000,
        "Label": {
          "Name": "Person",
          "Confidence": 97.59095764160156,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.29635533690452576,
                "Height": 0.5855528116226196,
                "Left": 0.4467882215976715,
                "Top": 0.23718678951263428
              },
              "Confidence": 97.65601348876953
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 6000,
        "Label": {
          "Name": "Photo",
          "Confidence": 65.62183380126953,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 6000,
        "Label": {
          "Name": "Photography",
          "Confidence": 65.62183380126953,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 6000,
        "Label": {
          "Name": "Sand",
          "Confidence": 61.37125778198242,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 6000,
        "Label": {
          "Name": "Sitting",
          "Confidence": 60.08395767211914,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 6000,
        "Label": {
          "Name": "Soil",
          "Confidence": 91.46035766601562,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 6500,
        "Label": {
          "Name": "Adventure",
          "Confidence": 53.96813201904297,
          "Instances": [],
          "Parents": [
            {
              "Name": "Leisure Activities"
            }
          ]
        }
      },
      {
        "Timestamp": 6500,
        "Label": {
          "Name": "Apparel",
          "Confidence": 82.57918548583984,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 6500,
        "Label": {
          "Name": "Clothing",
          "Confidence": 82.57918548583984,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 6500,
        "Label": {
          "Name": "Countryside",
          "Confidence": 61.76887130737305,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 6500,
        "Label": {
          "Name": "Desert",
          "Confidence": 54.8682746887207,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 6500,
        "Label": {
          "Name": "Field",
          "Confidence": 52.738834381103516,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 6500,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 55.0692138671875,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 6500,
        "Label": {
          "Name": "Grassland",
          "Confidence": 51.829063415527344,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Field"
            }
          ]
        }
      },
      {
        "Timestamp": 6500,
        "Label": {
          "Name": "Helmet",
          "Confidence": 82.57918548583984,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.09178559482097626,
                "Height": 0.11833102256059647,
                "Left": 0.33078673481941223,
                "Top": 0.7086487412452698
              },
              "Confidence": 80.82699584960938
            }
          ],
          "Parents": [
            {
              "Name": "Clothing"
            }
          ]
        }
      },
      {
        "Timestamp": 6500,
        "Label": {
          "Name": "Human",
          "Confidence": 97.36381530761719,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 6500,
        "Label": {
          "Name": "Leisure Activities",
          "Confidence": 53.96813201904297,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 6500,
        "Label": {
          "Name": "Nature",
          "Confidence": 94.24320220947266,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 6500,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 95.38646697998047,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 6500,
        "Label": {
          "Name": "Person",
          "Confidence": 97.36381530761719,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.2923733592033386,
                "Height": 0.5823749303817749,
                "Left": 0.4415823519229889,
                "Top": 0.24278922379016876
              },
              "Confidence": 97.15205383300781
            },
            {
              "BoundingBox": {
                "Width": 0.09916887432336807,
                "Height": 0.1216169148683548,
                "Left": 0.3270389139652252,
                "Top": 0.7030520439147949
              },
              "Confidence": 61.837162017822266
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 6500,
        "Label": {
          "Name": "Photo",
          "Confidence": 64.42781829833984,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 6500,
        "Label": {
          "Name": "Photography",
          "Confidence": 64.42781829833984,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 6500,
        "Label": {
          "Name": "Sand",
          "Confidence": 70.42115783691406,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 6500,
        "Label": {
          "Name": "Sitting",
          "Confidence": 58.91826248168945,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 6500,
        "Label": {
          "Name": "Sky",
          "Confidence": 50.086578369140625,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 6500,
        "Label": {
          "Name": "Soil",
          "Confidence": 91.73870849609375,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 7000,
        "Label": {
          "Name": "Adventure",
          "Confidence": 50.7564582824707,
          "Instances": [],
          "Parents": [
            {
              "Name": "Leisure Activities"
            }
          ]
        }
      },
      {
        "Timestamp": 7000,
        "Label": {
          "Name": "Apparel",
          "Confidence": 84.97766876220703,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 7000,
        "Label": {
          "Name": "Clothing",
          "Confidence": 84.97766876220703,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 7000,
        "Label": {
          "Name": "Countryside",
          "Confidence": 60.341339111328125,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 7000,
        "Label": {
          "Name": "Desert",
          "Confidence": 60.412864685058594,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 7000,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 57.547752380371094,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 7000,
        "Label": {
          "Name": "Helmet",
          "Confidence": 84.97766876220703,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.09356005489826202,
                "Height": 0.11547020822763443,
                "Left": 0.3208300769329071,
                "Top": 0.7118552327156067
              },
              "Confidence": 86.49821472167969
            }
          ],
          "Parents": [
            {
              "Name": "Clothing"
            }
          ]
        }
      },
      {
        "Timestamp": 7000,
        "Label": {
          "Name": "Human",
          "Confidence": 97.73037719726562,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 7000,
        "Label": {
          "Name": "Leisure Activities",
          "Confidence": 50.7564582824707,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 7000,
        "Label": {
          "Name": "Nature",
          "Confidence": 95.83914947509766,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 7000,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 95.55835723876953,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 7000,
        "Label": {
          "Name": "Person",
          "Confidence": 97.73037719726562,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.2939761281013489,
                "Height": 0.5788127183914185,
                "Left": 0.4319869875907898,
                "Top": 0.24467580020427704
              },
              "Confidence": 97.72319030761719
            },
            {
              "BoundingBox": {
                "Width": 0.09546470642089844,
                "Height": 0.11639946699142456,
                "Left": 0.3160994052886963,
                "Top": 0.707792341709137
              },
              "Confidence": 66.41239929199219
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 7000,
        "Label": {
          "Name": "Photo",
          "Confidence": 64.35697174072266,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 7000,
        "Label": {
          "Name": "Photography",
          "Confidence": 64.35697174072266,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 7000,
        "Label": {
          "Name": "Sand",
          "Confidence": 61.72386932373047,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 7000,
        "Label": {
          "Name": "Sitting",
          "Confidence": 58.12781524658203,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 7000,
        "Label": {
          "Name": "Sky",
          "Confidence": 51.301212310791016,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 7000,
        "Label": {
          "Name": "Soil",
          "Confidence": 85.39682006835938,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 7500,
        "Label": {
          "Name": "Apparel",
          "Confidence": 83.51543426513672,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 7500,
        "Label": {
          "Name": "Clothing",
          "Confidence": 83.51543426513672,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 7500,
        "Label": {
          "Name": "Countryside",
          "Confidence": 53.85166931152344,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 7500,
        "Label": {
          "Name": "Desert",
          "Confidence": 76.33145141601562,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 7500,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 50.33837890625,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 7500,
        "Label": {
          "Name": "Helmet",
          "Confidence": 83.51543426513672,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.09067092090845108,
                "Height": 0.11470069736242294,
                "Left": 0.3141421675682068,
                "Top": 0.7099915742874146
              },
              "Confidence": 84.44969940185547
            }
          ],
          "Parents": [
            {
              "Name": "Clothing"
            }
          ]
        }
      },
      {
        "Timestamp": 7500,
        "Label": {
          "Name": "Human",
          "Confidence": 98.31944274902344,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 7500,
        "Label": {
          "Name": "Nature",
          "Confidence": 97.38634490966797,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 7500,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 97.00585174560547,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 7500,
        "Label": {
          "Name": "Person",
          "Confidence": 98.31944274902344,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.29461222887039185,
                "Height": 0.5679998993873596,
                "Left": 0.42085951566696167,
                "Top": 0.25173327326774597
              },
              "Confidence": 98.330810546875
            },
            {
              "BoundingBox": {
                "Width": 0.0939154177904129,
                "Height": 0.11696862429380417,
                "Left": 0.30958065390586853,
                "Top": 0.7070170044898987
              },
              "Confidence": 47.32929229736328
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 7500,
        "Label": {
          "Name": "Photo",
          "Confidence": 65.84992980957031,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 7500,
        "Label": {
          "Name": "Photography",
          "Confidence": 65.84992980957031,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 7500,
        "Label": {
          "Name": "Sand",
          "Confidence": 78.32369995117188,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 7500,
        "Label": {
          "Name": "Sitting",
          "Confidence": 58.31330490112305,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 7500,
        "Label": {
          "Name": "Sky",
          "Confidence": 50.124725341796875,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 7500,
        "Label": {
          "Name": "Soil",
          "Confidence": 94.92321014404297,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 8000,
        "Label": {
          "Name": "Apparel",
          "Confidence": 82.60014343261719,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 8000,
        "Label": {
          "Name": "Clothing",
          "Confidence": 82.60014343261719,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 8000,
        "Label": {
          "Name": "Desert",
          "Confidence": 65.09423065185547,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 8000,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 51.296417236328125,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 8000,
        "Label": {
          "Name": "Helmet",
          "Confidence": 82.60014343261719,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.08924093097448349,
                "Height": 0.11672774702310562,
                "Left": 0.3085763156414032,
                "Top": 0.7040365934371948
              },
              "Confidence": 77.65798950195312
            }
          ],
          "Parents": [
            {
              "Name": "Clothing"
            }
          ]
        }
      },
      {
        "Timestamp": 8000,
        "Label": {
          "Name": "Human",
          "Confidence": 98.75897979736328,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 8000,
        "Label": {
          "Name": "Machine",
          "Confidence": 50.91692352294922,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 8000,
        "Label": {
          "Name": "Nature",
          "Confidence": 95.8499755859375,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 8000,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 95.32408905029297,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 8000,
        "Label": {
          "Name": "Person",
          "Confidence": 98.75897979736328,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.2845015525817871,
                "Height": 0.5710718631744385,
                "Left": 0.41622695326805115,
                "Top": 0.24273569881916046
              },
              "Confidence": 98.88072204589844
            },
            {
              "BoundingBox": {
                "Width": 0.09400363266468048,
                "Height": 0.12108684331178665,
                "Left": 0.30494970083236694,
                "Top": 0.7025899887084961
              },
              "Confidence": 72.48350524902344
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 8000,
        "Label": {
          "Name": "Photo",
          "Confidence": 66.25987243652344,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 8000,
        "Label": {
          "Name": "Photography",
          "Confidence": 66.25987243652344,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 8000,
        "Label": {
          "Name": "Sand",
          "Confidence": 74.56385803222656,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 8000,
        "Label": {
          "Name": "Sitting",
          "Confidence": 57.53429412841797,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 8000,
        "Label": {
          "Name": "Soil",
          "Confidence": 98.6355209350586,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 8000,
        "Label": {
          "Name": "Wheel",
          "Confidence": 50.91692352294922,
          "Instances": [],
          "Parents": [
            {
              "Name": "Machine"
            }
          ]
        }
      },
      {
        "Timestamp": 8500,
        "Label": {
          "Name": "Apparel",
          "Confidence": 81.93109893798828,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 8500,
        "Label": {
          "Name": "Clothing",
          "Confidence": 81.93109893798828,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 8500,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 54.58702087402344,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 8500,
        "Label": {
          "Name": "Helmet",
          "Confidence": 79.56674194335938,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.09173502773046494,
                "Height": 0.13604892790317535,
                "Left": 0.3039216995239258,
                "Top": 0.689026951789856
              },
              "Confidence": 95.95721435546875
            }
          ],
          "Parents": [
            {
              "Name": "Clothing"
            }
          ]
        }
      },
      {
        "Timestamp": 8500,
        "Label": {
          "Name": "Human",
          "Confidence": 98.8291244506836,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 8500,
        "Label": {
          "Name": "Nature",
          "Confidence": 75.03047180175781,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 8500,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 74.8139419555664,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 8500,
        "Label": {
          "Name": "Person",
          "Confidence": 98.8291244506836,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.3013380169868469,
                "Height": 0.5733433961868286,
                "Left": 0.40021222829818726,
                "Top": 0.23638510704040527
              },
              "Confidence": 98.81256103515625
            },
            {
              "BoundingBox": {
                "Width": 0.08847489207983017,
                "Height": 0.13378244638442993,
                "Left": 0.3071354925632477,
                "Top": 0.6889301538467407
              },
              "Confidence": 53.11363220214844
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 8500,
        "Label": {
          "Name": "Photo",
          "Confidence": 51.99510192871094,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 8500,
        "Label": {
          "Name": "Photography",
          "Confidence": 51.99510192871094,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 8500,
        "Label": {
          "Name": "Soil",
          "Confidence": 78.7969741821289,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 9000,
        "Label": {
          "Name": "Apparel",
          "Confidence": 54.506797790527344,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 9000,
        "Label": {
          "Name": "Clothing",
          "Confidence": 54.506797790527344,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 9000,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 56.86241149902344,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 9000,
        "Label": {
          "Name": "Grand Theft Auto",
          "Confidence": 59.79548645019531,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 9000,
        "Label": {
          "Name": "Human",
          "Confidence": 98.86170959472656,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 9000,
        "Label": {
          "Name": "Person",
          "Confidence": 98.86170959472656,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.38341957330703735,
                "Height": 0.6151643395423889,
                "Left": 0.14075051248073578,
                "Top": 0.22346246242523193
              },
              "Confidence": 98.82850646972656
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 9500,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 58.57651138305664,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 9500,
        "Label": {
          "Name": "Grand Theft Auto",
          "Confidence": 62.513389587402344,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 9500,
        "Label": {
          "Name": "Human",
          "Confidence": 98.9919204711914,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 9500,
        "Label": {
          "Name": "Person",
          "Confidence": 98.9919204711914,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.38814741373062134,
                "Height": 0.6120166182518005,
                "Left": 0.13868623971939087,
                "Top": 0.22477826476097107
              },
              "Confidence": 99.01298522949219
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 9999,
        "Label": {
          "Name": "Animal",
          "Confidence": 50.47312927246094,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 9999,
        "Label": {
          "Name": "Apparel",
          "Confidence": 51.347190856933594,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 9999,
        "Label": {
          "Name": "Bird",
          "Confidence": 50.47312927246094,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.173780158162117,
                "Height": 0.22783640027046204,
                "Left": 0.46473485231399536,
                "Top": 0.5996280908584595
              },
              "Confidence": 65.13999938964844
            }
          ],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 9999,
        "Label": {
          "Name": "Clothing",
          "Confidence": 51.347190856933594,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 9999,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 65.53553009033203,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 9999,
        "Label": {
          "Name": "Grand Theft Auto",
          "Confidence": 56.0931510925293,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 9999,
        "Label": {
          "Name": "Human",
          "Confidence": 99.07845306396484,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 9999,
        "Label": {
          "Name": "Person",
          "Confidence": 99.07845306396484,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.3852556645870209,
                "Height": 0.5977766513824463,
                "Left": 0.1349162608385086,
                "Top": 0.2267683446407318
              },
              "Confidence": 99.09050750732422
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 10499,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 69.96063995361328,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 10499,
        "Label": {
          "Name": "Grand Theft Auto",
          "Confidence": 55.3380241394043,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 10499,
        "Label": {
          "Name": "Human",
          "Confidence": 99.10665130615234,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 10499,
        "Label": {
          "Name": "Person",
          "Confidence": 99.10665130615234,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.3784594237804413,
                "Height": 0.6067054867744446,
                "Left": 0.1389250010251999,
                "Top": 0.22928103804588318
              },
              "Confidence": 99.10682678222656
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 10999,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 61.92702865600586,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 10999,
        "Label": {
          "Name": "Grand Theft Auto",
          "Confidence": 56.320980072021484,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 10999,
        "Label": {
          "Name": "Human",
          "Confidence": 99.12158203125,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 10999,
        "Label": {
          "Name": "Person",
          "Confidence": 99.12158203125,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.37193283438682556,
                "Height": 0.6072297692298889,
                "Left": 0.1387389600276947,
                "Top": 0.22861792147159576
              },
              "Confidence": 99.12218475341797
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 11499,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 58.36500930786133,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 11499,
        "Label": {
          "Name": "Grand Theft Auto",
          "Confidence": 52.37623977661133,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 11499,
        "Label": {
          "Name": "Human",
          "Confidence": 99.19676971435547,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 11499,
        "Label": {
          "Name": "Person",
          "Confidence": 99.19676971435547,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.36836135387420654,
                "Height": 0.6063933372497559,
                "Left": 0.1395399272441864,
                "Top": 0.22906824946403503
              },
              "Confidence": 99.13442993164062
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 11999,
        "Label": {
          "Name": "Face",
          "Confidence": 79.7672348022461,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 11999,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 54.962223052978516,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 11999,
        "Label": {
          "Name": "Halo",
          "Confidence": 53.78968048095703,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 11999,
        "Label": {
          "Name": "Head",
          "Confidence": 51.68346405029297,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 11999,
        "Label": {
          "Name": "Human",
          "Confidence": 99.29370880126953,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 11999,
        "Label": {
          "Name": "Person",
          "Confidence": 99.29370880126953,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.701704204082489,
                "Height": 0.6798826456069946,
                "Left": 0.2069627046585083,
                "Top": 0.1546783298254013
              },
              "Confidence": 96.39451599121094
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 11999,
        "Label": {
          "Name": "Photo",
          "Confidence": 52.93111038208008,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 11999,
        "Label": {
          "Name": "Photography",
          "Confidence": 52.93111038208008,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 11999,
        "Label": {
          "Name": "Portrait",
          "Confidence": 52.93111038208008,
          "Instances": [],
          "Parents": [
            {
              "Name": "Face"
            },
            {
              "Name": "Photography"
            },
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 12499,
        "Label": {
          "Name": "Face",
          "Confidence": 99.11300659179688,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 12499,
        "Label": {
          "Name": "Female",
          "Confidence": 52.50102233886719,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 12499,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 54.294578552246094,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 12499,
        "Label": {
          "Name": "Halo",
          "Confidence": 56.7520866394043,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 12499,
        "Label": {
          "Name": "Head",
          "Confidence": 54.296138763427734,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 12499,
        "Label": {
          "Name": "Human",
          "Confidence": 99.11300659179688,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 12499,
        "Label": {
          "Name": "Person",
          "Confidence": 99.11300659179688,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.7036165595054626,
                "Height": 0.6805757284164429,
                "Left": 0.19470401108264923,
                "Top": 0.1541052907705307
              },
              "Confidence": 96.75181579589844
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 12499,
        "Label": {
          "Name": "Photo",
          "Confidence": 64.59362030029297,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 12499,
        "Label": {
          "Name": "Photography",
          "Confidence": 64.59362030029297,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 12499,
        "Label": {
          "Name": "Portrait",
          "Confidence": 64.59362030029297,
          "Instances": [],
          "Parents": [
            {
              "Name": "Face"
            },
            {
              "Name": "Photography"
            },
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 12999,
        "Label": {
          "Name": "Face",
          "Confidence": 99.2640609741211,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 12999,
        "Label": {
          "Name": "Female",
          "Confidence": 57.304691314697266,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 12999,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 57.302894592285156,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 12999,
        "Label": {
          "Name": "Halo",
          "Confidence": 57.23193359375,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 12999,
        "Label": {
          "Name": "Head",
          "Confidence": 56.02070999145508,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 12999,
        "Label": {
          "Name": "Human",
          "Confidence": 99.2640609741211,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 12999,
        "Label": {
          "Name": "Person",
          "Confidence": 99.2640609741211,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.6853799819946289,
                "Height": 0.7120696902275085,
                "Left": 0.2021835595369339,
                "Top": 0.14982779324054718
              },
              "Confidence": 97.26313781738281
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 12999,
        "Label": {
          "Name": "Photo",
          "Confidence": 65.03459930419922,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 12999,
        "Label": {
          "Name": "Photography",
          "Confidence": 65.03459930419922,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 12999,
        "Label": {
          "Name": "Portrait",
          "Confidence": 65.03459930419922,
          "Instances": [],
          "Parents": [
            {
              "Name": "Face"
            },
            {
              "Name": "Photography"
            },
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 13499,
        "Label": {
          "Name": "Face",
          "Confidence": 99.37332916259766,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 13499,
        "Label": {
          "Name": "Female",
          "Confidence": 60.245384216308594,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 13499,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 58.27623748779297,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 13499,
        "Label": {
          "Name": "Halo",
          "Confidence": 57.93341827392578,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 13499,
        "Label": {
          "Name": "Head",
          "Confidence": 63.99941635131836,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 13499,
        "Label": {
          "Name": "Human",
          "Confidence": 99.37332916259766,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 13499,
        "Label": {
          "Name": "Person",
          "Confidence": 99.37332916259766,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.7279332280158997,
                "Height": 0.6746916770935059,
                "Left": 0.18005073070526123,
                "Top": 0.16205808520317078
              },
              "Confidence": 97.67925262451172
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 13499,
        "Label": {
          "Name": "Photo",
          "Confidence": 64.52239990234375,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 13499,
        "Label": {
          "Name": "Photography",
          "Confidence": 64.52239990234375,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 13499,
        "Label": {
          "Name": "Portrait",
          "Confidence": 64.52239990234375,
          "Instances": [],
          "Parents": [
            {
              "Name": "Face"
            },
            {
              "Name": "Photography"
            },
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 13999,
        "Label": {
          "Name": "Face",
          "Confidence": 99.3662338256836,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 13999,
        "Label": {
          "Name": "Female",
          "Confidence": 53.341087341308594,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 13999,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 56.976383209228516,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 13999,
        "Label": {
          "Name": "Halo",
          "Confidence": 63.962528228759766,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 13999,
        "Label": {
          "Name": "Head",
          "Confidence": 54.98991394042969,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 13999,
        "Label": {
          "Name": "Human",
          "Confidence": 99.3662338256836,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 13999,
        "Label": {
          "Name": "Person",
          "Confidence": 99.3662338256836,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.6873742938041687,
                "Height": 0.6813457012176514,
                "Left": 0.19174423813819885,
                "Top": 0.16111408174037933
              },
              "Confidence": 97.4250259399414
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 13999,
        "Label": {
          "Name": "Photo",
          "Confidence": 61.717899322509766,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 13999,
        "Label": {
          "Name": "Photography",
          "Confidence": 61.717899322509766,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 13999,
        "Label": {
          "Name": "Portrait",
          "Confidence": 61.717899322509766,
          "Instances": [],
          "Parents": [
            {
              "Name": "Face"
            },
            {
              "Name": "Photography"
            },
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 14499,
        "Label": {
          "Name": "Face",
          "Confidence": 99.58818817138672,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 14499,
        "Label": {
          "Name": "Female",
          "Confidence": 51.880672454833984,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 14499,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 52.14602279663086,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 14499,
        "Label": {
          "Name": "Halo",
          "Confidence": 57.54580307006836,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 14499,
        "Label": {
          "Name": "Head",
          "Confidence": 54.8666877746582,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 14499,
        "Label": {
          "Name": "Human",
          "Confidence": 99.58818817138672,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 14499,
        "Label": {
          "Name": "Person",
          "Confidence": 99.58818817138672,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.7106106877326965,
                "Height": 0.6653071641921997,
                "Left": 0.1738429069519043,
                "Top": 0.16445325314998627
              },
              "Confidence": 97.11080932617188
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 14499,
        "Label": {
          "Name": "Photo",
          "Confidence": 60.888084411621094,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 14499,
        "Label": {
          "Name": "Photography",
          "Confidence": 60.888084411621094,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 14499,
        "Label": {
          "Name": "Portrait",
          "Confidence": 60.888084411621094,
          "Instances": [],
          "Parents": [
            {
              "Name": "Face"
            },
            {
              "Name": "Photography"
            },
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 14999,
        "Label": {
          "Name": "Face",
          "Confidence": 99.84864044189453,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 14999,
        "Label": {
          "Name": "Female",
          "Confidence": 56.61579895019531,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 14999,
        "Label": {
          "Name": "Halo",
          "Confidence": 51.94572830200195,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 14999,
        "Label": {
          "Name": "Head",
          "Confidence": 59.62232208251953,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 14999,
        "Label": {
          "Name": "Human",
          "Confidence": 99.84864044189453,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 14999,
        "Label": {
          "Name": "Person",
          "Confidence": 99.84864044189453,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.652485191822052,
                "Height": 0.6896383762359619,
                "Left": 0.21979586780071259,
                "Top": 0.1549699604511261
              },
              "Confidence": 96.73863220214844
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 14999,
        "Label": {
          "Name": "Photo",
          "Confidence": 62.35110092163086,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 14999,
        "Label": {
          "Name": "Photography",
          "Confidence": 62.35110092163086,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 14999,
        "Label": {
          "Name": "Portrait",
          "Confidence": 62.35110092163086,
          "Instances": [],
          "Parents": [
            {
              "Name": "Face"
            },
            {
              "Name": "Photography"
            },
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 15499,
        "Label": {
          "Name": "Face",
          "Confidence": 80.255859375,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 15499,
        "Label": {
          "Name": "Human",
          "Confidence": 80.255859375,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 15499,
        "Label": {
          "Name": "Person",
          "Confidence": 80.255859375,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.6450029611587524,
                "Height": 0.6651899814605713,
                "Left": 0.23263247311115265,
                "Top": 0.16707967221736908
              },
              "Confidence": 97.96278381347656
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 15499,
        "Label": {
          "Name": "Photo",
          "Confidence": 56.12291717529297,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 15499,
        "Label": {
          "Name": "Photography",
          "Confidence": 56.12291717529297,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 15999,
        "Label": {
          "Name": "Landscape",
          "Confidence": 80.07129669189453,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 15999,
        "Label": {
          "Name": "Nature",
          "Confidence": 80.1492691040039,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 15999,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 80.07129669189453,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 15999,
        "Label": {
          "Name": "Panoramic",
          "Confidence": 80.07129669189453,
          "Instances": [],
          "Parents": [
            {
              "Name": "Landscape"
            },
            {
              "Name": "Scenery"
            },
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 15999,
        "Label": {
          "Name": "Scenery",
          "Confidence": 80.07129669189453,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 15999,
        "Label": {
          "Name": "Sky",
          "Confidence": 50.1541748046875,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 16499,
        "Label": {
          "Name": "Desert",
          "Confidence": 56.46267318725586,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 16499,
        "Label": {
          "Name": "Horizon",
          "Confidence": 55.61115646362305,
          "Instances": [],
          "Parents": [
            {
              "Name": "Sky"
            },
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 16499,
        "Label": {
          "Name": "Human",
          "Confidence": 77.5606689453125,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 16499,
        "Label": {
          "Name": "Landscape",
          "Confidence": 94.4797134399414,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 16499,
        "Label": {
          "Name": "Nature",
          "Confidence": 99.64322662353516,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 16499,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 99.27706146240234,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 16499,
        "Label": {
          "Name": "Panoramic",
          "Confidence": 94.4797134399414,
          "Instances": [],
          "Parents": [
            {
              "Name": "Landscape"
            },
            {
              "Name": "Scenery"
            },
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 16499,
        "Label": {
          "Name": "Person",
          "Confidence": 77.5606689453125,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.12525025010108948,
                "Height": 0.11820988357067108,
                "Left": 0.42330312728881836,
                "Top": 0.7038558721542358
              },
              "Confidence": 96.61222076416016
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 16499,
        "Label": {
          "Name": "Photo",
          "Confidence": 58.747520446777344,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 16499,
        "Label": {
          "Name": "Photography",
          "Confidence": 58.747520446777344,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 16499,
        "Label": {
          "Name": "Scenery",
          "Confidence": 94.4797134399414,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 16499,
        "Label": {
          "Name": "Sky",
          "Confidence": 61.723388671875,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 16499,
        "Label": {
          "Name": "Sunrise",
          "Confidence": 50.483543395996094,
          "Instances": [],
          "Parents": [
            {
              "Name": "Sky"
            },
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 16999,
        "Label": {
          "Name": "Desert",
          "Confidence": 54.370750427246094,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 16999,
        "Label": {
          "Name": "Grand Theft Auto",
          "Confidence": 52.048744201660156,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 16999,
        "Label": {
          "Name": "Horizon",
          "Confidence": 52.41301727294922,
          "Instances": [],
          "Parents": [
            {
              "Name": "Sky"
            },
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 16999,
        "Label": {
          "Name": "Human",
          "Confidence": 96.78897094726562,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 16999,
        "Label": {
          "Name": "Landscape",
          "Confidence": 64.69310760498047,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 16999,
        "Label": {
          "Name": "Nature",
          "Confidence": 96.69438171386719,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 16999,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 93.6242904663086,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 16999,
        "Label": {
          "Name": "Panoramic",
          "Confidence": 64.69310760498047,
          "Instances": [],
          "Parents": [
            {
              "Name": "Landscape"
            },
            {
              "Name": "Scenery"
            },
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 16999,
        "Label": {
          "Name": "People",
          "Confidence": 53.12770080566406,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 16999,
        "Label": {
          "Name": "Person",
          "Confidence": 96.78897094726562,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.1760692596435547,
                "Height": 0.23146891593933105,
                "Left": 0.3552761673927307,
                "Top": 0.5923961400985718
              },
              "Confidence": 96.50114440917969
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 16999,
        "Label": {
          "Name": "Photo",
          "Confidence": 56.41463088989258,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 16999,
        "Label": {
          "Name": "Photography",
          "Confidence": 56.41463088989258,
          "Instances": [],
          "Parents": [
            {
              "Name": "Person"
            }
          ]
        }
      },
      {
        "Timestamp": 16999,
        "Label": {
          "Name": "Scenery",
          "Confidence": 68.00486755371094,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 16999,
        "Label": {
          "Name": "Sky",
          "Confidence": 57.19444274902344,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 16999,
        "Label": {
          "Name": "Sunrise",
          "Confidence": 50.45930862426758,
          "Instances": [],
          "Parents": [
            {
              "Name": "Sky"
            },
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 17499,
        "Label": {
          "Name": "Grand Theft Auto",
          "Confidence": 72.80967712402344,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 17499,
        "Label": {
          "Name": "Human",
          "Confidence": 96.94767761230469,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 17499,
        "Label": {
          "Name": "Nature",
          "Confidence": 75.48247528076172,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 17499,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 67.34500122070312,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 17499,
        "Label": {
          "Name": "Person",
          "Confidence": 96.94767761230469,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.1679694950580597,
                "Height": 0.3193243145942688,
                "Left": 0.33812767267227173,
                "Top": 0.4995037615299225
              },
              "Confidence": 97.8512954711914
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 17999,
        "Label": {
          "Name": "Grand Theft Auto",
          "Confidence": 77.28599548339844,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 17999,
        "Label": {
          "Name": "Human",
          "Confidence": 95.42822265625,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 17999,
        "Label": {
          "Name": "Person",
          "Confidence": 95.42822265625,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.16361960768699646,
                "Height": 0.3922424018383026,
                "Left": 0.3343498706817627,
                "Top": 0.4250132739543915
              },
              "Confidence": 94.61383056640625
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 18499,
        "Label": {
          "Name": "Grand Theft Auto",
          "Confidence": 75.18113708496094,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 18499,
        "Label": {
          "Name": "Human",
          "Confidence": 95.4514389038086,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 18499,
        "Label": {
          "Name": "Person",
          "Confidence": 95.4514389038086,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.14886856079101562,
                "Height": 0.4364674985408783,
                "Left": 0.33635130524635315,
                "Top": 0.391074538230896
              },
              "Confidence": 95.51094818115234
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 18999,
        "Label": {
          "Name": "Grand Theft Auto",
          "Confidence": 66.33077239990234,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 18999,
        "Label": {
          "Name": "Horizon",
          "Confidence": 52.22420120239258,
          "Instances": [],
          "Parents": [
            {
              "Name": "Sky"
            },
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 18999,
        "Label": {
          "Name": "Human",
          "Confidence": 96.18446350097656,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 18999,
        "Label": {
          "Name": "Nature",
          "Confidence": 59.05596160888672,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 18999,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 52.22420120239258,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 18999,
        "Label": {
          "Name": "Person",
          "Confidence": 96.18446350097656,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.10964898765087128,
                "Height": 0.4579903483390808,
                "Left": 0.33260005712509155,
                "Top": 0.3694206178188324
              },
              "Confidence": 96.10594177246094
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 18999,
        "Label": {
          "Name": "Sky",
          "Confidence": 52.22420120239258,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 19499,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 57.47541046142578,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 19499,
        "Label": {
          "Name": "Grand Theft Auto",
          "Confidence": 58.12577438354492,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 19499,
        "Label": {
          "Name": "Human",
          "Confidence": 96.76654815673828,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 19499,
        "Label": {
          "Name": "Nature",
          "Confidence": 52.30523681640625,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 19499,
        "Label": {
          "Name": "Person",
          "Confidence": 96.76654815673828,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.09496438503265381,
                "Height": 0.4554331600666046,
                "Left": 0.33337289094924927,
                "Top": 0.3655742108821869
              },
              "Confidence": 97.09954833984375
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 20000,
        "Label": {
          "Name": "Final Fantasy",
          "Confidence": 64.2511978149414,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 20000,
        "Label": {
          "Name": "Grand Theft Auto",
          "Confidence": 52.33436584472656,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 20000,
        "Label": {
          "Name": "Human",
          "Confidence": 96.5735092163086,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 20000,
        "Label": {
          "Name": "Nature",
          "Confidence": 52.10616683959961,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 20000,
        "Label": {
          "Name": "Person",
          "Confidence": 96.5735092163086,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.09770605713129044,
                "Height": 0.45872294902801514,
                "Left": 0.3310029208660126,
                "Top": 0.36264148354530334
              },
              "Confidence": 96.40253448486328
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 20208,
        "Label": {
          "Name": "Animal",
          "Confidence": 80.08555603027344,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 20208,
        "Label": {
          "Name": "Bird",
          "Confidence": 80.08555603027344,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.02053222618997097,
                "Height": 0.11206597089767456,
                "Left": 0.4016547203063965,
                "Top": 0.3978290557861328
              },
              "Confidence": 85.30921936035156
            }
          ],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 20208,
        "Label": {
          "Name": "Buffalo",
          "Confidence": 55.86650466918945,
          "Instances": [],
          "Parents": [
            {
              "Name": "Wildlife"
            },
            {
              "Name": "Mammal"
            },
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 20208,
        "Label": {
          "Name": "Building",
          "Confidence": 55.31309127807617,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 20208,
        "Label": {
          "Name": "Call of Duty",
          "Confidence": 52.39997100830078,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 20208,
        "Label": {
          "Name": "Field",
          "Confidence": 58.99043655395508,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 20208,
        "Label": {
          "Name": "Human",
          "Confidence": 75.65655517578125,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 20208,
        "Label": {
          "Name": "Mammal",
          "Confidence": 55.86650466918945,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 20208,
        "Label": {
          "Name": "Nature",
          "Confidence": 59.229576110839844,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 20208,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 67.64128875732422,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 20208,
        "Label": {
          "Name": "Person",
          "Confidence": 75.65655517578125,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.018131637945771217,
                "Height": 0.11097463220357895,
                "Left": 0.40315061807632446,
                "Top": 0.4043392241001129
              },
              "Confidence": 71.68579864501953
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 20208,
        "Label": {
          "Name": "Transportation",
          "Confidence": 59.79731750488281,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 20208,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 59.79731750488281,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 20208,
        "Label": {
          "Name": "Wildlife",
          "Confidence": 55.86650466918945,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 20708,
        "Label": {
          "Name": "Animal",
          "Confidence": 74.37324523925781,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 20708,
        "Label": {
          "Name": "Bird",
          "Confidence": 74.37324523925781,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.020347118377685547,
                "Height": 0.11100734770298004,
                "Left": 0.3983151316642761,
                "Top": 0.4105132222175598
              },
              "Confidence": 64.01273345947266
            }
          ],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 20708,
        "Label": {
          "Name": "Buffalo",
          "Confidence": 58.042198181152344,
          "Instances": [],
          "Parents": [
            {
              "Name": "Wildlife"
            },
            {
              "Name": "Mammal"
            },
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 20708,
        "Label": {
          "Name": "Building",
          "Confidence": 65.06448364257812,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 20708,
        "Label": {
          "Name": "Call of Duty",
          "Confidence": 51.89727020263672,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 20708,
        "Label": {
          "Name": "Field",
          "Confidence": 61.05719757080078,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 20708,
        "Label": {
          "Name": "Housing",
          "Confidence": 51.793949127197266,
          "Instances": [],
          "Parents": [
            {
              "Name": "Building"
            }
          ]
        }
      },
      {
        "Timestamp": 20708,
        "Label": {
          "Name": "Human",
          "Confidence": 67.3770523071289,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 20708,
        "Label": {
          "Name": "Mammal",
          "Confidence": 58.042198181152344,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 20708,
        "Label": {
          "Name": "Nature",
          "Confidence": 60.0917854309082,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 20708,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 69.80386352539062,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 20708,
        "Label": {
          "Name": "Person",
          "Confidence": 67.3770523071289,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.017470836639404297,
                "Height": 0.11035758256912231,
                "Left": 0.3995944857597351,
                "Top": 0.41140425205230713
              },
              "Confidence": 87.8742446899414
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 20708,
        "Label": {
          "Name": "Transportation",
          "Confidence": 51.17782974243164,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 20708,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 51.17782974243164,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 20708,
        "Label": {
          "Name": "Wildlife",
          "Confidence": 58.042198181152344,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 21208,
        "Label": {
          "Name": "Animal",
          "Confidence": 88.878173828125,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 21208,
        "Label": {
          "Name": "Bird",
          "Confidence": 88.878173828125,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.02115790918469429,
                "Height": 0.11871295422315598,
                "Left": 0.3968396782875061,
                "Top": 0.42109668254852295
              },
              "Confidence": 95.31576538085938
            },
            {
              "BoundingBox": {
                "Width": 0.00720558175817132,
                "Height": 0.019560664892196655,
                "Left": 0.7699898481369019,
                "Top": 0.3783465623855591
              },
              "Confidence": 66.63733673095703
            }
          ],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 21208,
        "Label": {
          "Name": "Buffalo",
          "Confidence": 58.20063018798828,
          "Instances": [],
          "Parents": [
            {
              "Name": "Wildlife"
            },
            {
              "Name": "Mammal"
            },
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 21208,
        "Label": {
          "Name": "Building",
          "Confidence": 57.710079193115234,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 21208,
        "Label": {
          "Name": "Field",
          "Confidence": 60.74722671508789,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 21208,
        "Label": {
          "Name": "Mammal",
          "Confidence": 58.20063018798828,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 21208,
        "Label": {
          "Name": "Nature",
          "Confidence": 63.70996856689453,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 21208,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 74.13139343261719,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 21208,
        "Label": {
          "Name": "Transportation",
          "Confidence": 57.167049407958984,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 21208,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 57.167049407958984,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 21208,
        "Label": {
          "Name": "Wildlife",
          "Confidence": 58.20063018798828,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 21708,
        "Label": {
          "Name": "Animal",
          "Confidence": 93.3388900756836,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 21708,
        "Label": {
          "Name": "Bird",
          "Confidence": 93.3388900756836,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.021903038024902344,
                "Height": 0.11859223991632462,
                "Left": 0.40582841634750366,
                "Top": 0.43472912907600403
              },
              "Confidence": 93.93560791015625
            },
            {
              "BoundingBox": {
                "Width": 0.016576766967773438,
                "Height": 0.01833953894674778,
                "Left": 0.7607521414756775,
                "Top": 0.45676201581954956
              },
              "Confidence": 70.80522918701172
            },
            {
              "BoundingBox": {
                "Width": 0.007241630461066961,
                "Height": 0.017633819952607155,
                "Left": 0.7562159299850464,
                "Top": 0.3795093595981598
              },
              "Confidence": 63.699283599853516
            }
          ],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 21708,
        "Label": {
          "Name": "Buffalo",
          "Confidence": 56.45804214477539,
          "Instances": [],
          "Parents": [
            {
              "Name": "Wildlife"
            },
            {
              "Name": "Mammal"
            },
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 21708,
        "Label": {
          "Name": "Field",
          "Confidence": 58.49528121948242,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 21708,
        "Label": {
          "Name": "Ground",
          "Confidence": 51.6820068359375,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 21708,
        "Label": {
          "Name": "Land",
          "Confidence": 54.84296798706055,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 21708,
        "Label": {
          "Name": "Mammal",
          "Confidence": 56.45804214477539,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 21708,
        "Label": {
          "Name": "Nature",
          "Confidence": 69.3359603881836,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 21708,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 80.05638122558594,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 21708,
        "Label": {
          "Name": "Transportation",
          "Confidence": 61.1926155090332,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 21708,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 61.04448699951172,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 21708,
        "Label": {
          "Name": "Wildlife",
          "Confidence": 56.45804214477539,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 22208,
        "Label": {
          "Name": "Animal",
          "Confidence": 92.01179504394531,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 22208,
        "Label": {
          "Name": "Bird",
          "Confidence": 92.01179504394531,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.02690286561846733,
                "Height": 0.12725508213043213,
                "Left": 0.41894540190696716,
                "Top": 0.446311354637146
              },
              "Confidence": 89.52593231201172
            },
            {
              "BoundingBox": {
                "Width": 0.016129206866025925,
                "Height": 0.017895422875881195,
                "Left": 0.7525840997695923,
                "Top": 0.4608626067638397
              },
              "Confidence": 61.068115234375
            }
          ],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 22208,
        "Label": {
          "Name": "Buffalo",
          "Confidence": 56.56218338012695,
          "Instances": [],
          "Parents": [
            {
              "Name": "Wildlife"
            },
            {
              "Name": "Mammal"
            },
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 22208,
        "Label": {
          "Name": "Field",
          "Confidence": 61.51759719848633,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 22208,
        "Label": {
          "Name": "Ground",
          "Confidence": 50.28553771972656,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 22208,
        "Label": {
          "Name": "Human",
          "Confidence": 50.791141510009766,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 22208,
        "Label": {
          "Name": "Mammal",
          "Confidence": 57.20521926879883,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 22208,
        "Label": {
          "Name": "Nature",
          "Confidence": 65.8367919921875,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 22208,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 77.6443862915039,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 22208,
        "Label": {
          "Name": "Person",
          "Confidence": 50.791141510009766,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.022754479199647903,
                "Height": 0.11597824096679688,
                "Left": 0.4208441376686096,
                "Top": 0.45163291692733765
              },
              "Confidence": 69.55713653564453
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 22208,
        "Label": {
          "Name": "Transportation",
          "Confidence": 60.17630386352539,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 22208,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 59.628997802734375,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 22208,
        "Label": {
          "Name": "Wildlife",
          "Confidence": 56.56218338012695,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 22708,
        "Label": {
          "Name": "Animal",
          "Confidence": 95.72425842285156,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 22708,
        "Label": {
          "Name": "Bird",
          "Confidence": 95.72425842285156,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.027314281091094017,
                "Height": 0.12300075590610504,
                "Left": 0.43534359335899353,
                "Top": 0.45582669973373413
              },
              "Confidence": 97.73677062988281
            },
            {
              "BoundingBox": {
                "Width": 0.016823481768369675,
                "Height": 0.01943579688668251,
                "Left": 0.7428106665611267,
                "Top": 0.46162301301956177
              },
              "Confidence": 71.93124389648438
            },
            {
              "BoundingBox": {
                "Width": 0.00699272146448493,
                "Height": 0.01741502620279789,
                "Left": 0.7383058071136475,
                "Top": 0.38467589020729065
              },
              "Confidence": 63.7505989074707
            }
          ],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 22708,
        "Label": {
          "Name": "Buffalo",
          "Confidence": 59.83195114135742,
          "Instances": [],
          "Parents": [
            {
              "Name": "Wildlife"
            },
            {
              "Name": "Mammal"
            },
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 22708,
        "Label": {
          "Name": "Mammal",
          "Confidence": 61.810543060302734,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 22708,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 59.97505569458008,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 22708,
        "Label": {
          "Name": "Transportation",
          "Confidence": 51.38100814819336,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 22708,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 50.9513053894043,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 22708,
        "Label": {
          "Name": "Wildlife",
          "Confidence": 59.83195114135742,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 23208,
        "Label": {
          "Name": "Animal",
          "Confidence": 91.62876892089844,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 23208,
        "Label": {
          "Name": "Bird",
          "Confidence": 91.62876892089844,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.025237560272216797,
                "Height": 0.1273518055677414,
                "Left": 0.4536174237728119,
                "Top": 0.4695582985877991
              },
              "Confidence": 95.7302474975586
            },
            {
              "BoundingBox": {
                "Width": 0.009084319695830345,
                "Height": 0.019927045330405235,
                "Left": 0.7308122515678406,
                "Top": 0.3858208954334259
              },
              "Confidence": 74.78707122802734
            },
            {
              "BoundingBox": {
                "Width": 0.017466355115175247,
                "Height": 0.019519466906785965,
                "Left": 0.7389086484909058,
                "Top": 0.4632193148136139
              },
              "Confidence": 72.045166015625
            },
            {
              "BoundingBox": {
                "Width": 0.014657306484878063,
                "Height": 0.023392656818032265,
                "Left": 0.7626969218254089,
                "Top": 0.4528200328350067
              },
              "Confidence": 69.33796691894531
            }
          ],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 23208,
        "Label": {
          "Name": "Buffalo",
          "Confidence": 57.72237777709961,
          "Instances": [],
          "Parents": [
            {
              "Name": "Wildlife"
            },
            {
              "Name": "Mammal"
            },
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 23208,
        "Label": {
          "Name": "Call of Duty",
          "Confidence": 51.732391357421875,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 23208,
        "Label": {
          "Name": "Hunting",
          "Confidence": 52.009700775146484,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 23208,
        "Label": {
          "Name": "Mammal",
          "Confidence": 58.365413665771484,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 23208,
        "Label": {
          "Name": "Wildlife",
          "Confidence": 57.72237777709961,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 23708,
        "Label": {
          "Name": "Airfield",
          "Confidence": 50.63053894042969,
          "Instances": [],
          "Parents": [
            {
              "Name": "Airport"
            }
          ]
        }
      },
      {
        "Timestamp": 23708,
        "Label": {
          "Name": "Airport",
          "Confidence": 50.63053894042969,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 23708,
        "Label": {
          "Name": "Animal",
          "Confidence": 81.59504699707031,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 23708,
        "Label": {
          "Name": "Bird",
          "Confidence": 81.59504699707031,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.028340721502900124,
                "Height": 0.13385789096355438,
                "Left": 0.4678826332092285,
                "Top": 0.480118066072464
              },
              "Confidence": 72.90079498291016
            },
            {
              "BoundingBox": {
                "Width": 0.007343292236328125,
                "Height": 0.01785074919462204,
                "Left": 0.7206651568412781,
                "Top": 0.38819724321365356
              },
              "Confidence": 71.59624481201172
            },
            {
              "BoundingBox": {
                "Width": 0.014444160275161266,
                "Height": 0.022021399810910225,
                "Left": 0.7535992860794067,
                "Top": 0.458231657743454
              },
              "Confidence": 71.08001708984375
            },
            {
              "BoundingBox": {
                "Width": 0.017665768042206764,
                "Height": 0.017798613756895065,
                "Left": 0.729225218296051,
                "Top": 0.46730443835258484
              },
              "Confidence": 62.30719757080078
            }
          ],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 23708,
        "Label": {
          "Name": "Buffalo",
          "Confidence": 54.99082946777344,
          "Instances": [],
          "Parents": [
            {
              "Name": "Wildlife"
            },
            {
              "Name": "Mammal"
            },
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 23708,
        "Label": {
          "Name": "Field",
          "Confidence": 50.843265533447266,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 23708,
        "Label": {
          "Name": "Human",
          "Confidence": 65.28045654296875,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 23708,
        "Label": {
          "Name": "Mammal",
          "Confidence": 54.99082946777344,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 23708,
        "Label": {
          "Name": "Nature",
          "Confidence": 69.22018432617188,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 23708,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 73.02930450439453,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 23708,
        "Label": {
          "Name": "Person",
          "Confidence": 65.28045654296875,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.022481728345155716,
                "Height": 0.11947225034236908,
                "Left": 0.4708526134490967,
                "Top": 0.48797866702079773
              },
              "Confidence": 82.910888671875
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 23708,
        "Label": {
          "Name": "Wildlife",
          "Confidence": 54.99082946777344,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 24208,
        "Label": {
          "Name": "Animal",
          "Confidence": 81.40995788574219,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 24208,
        "Label": {
          "Name": "Bird",
          "Confidence": 71.45703125,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.03033456765115261,
                "Height": 0.1335923969745636,
                "Left": 0.4807300567626953,
                "Top": 0.4917431175708771
              },
              "Confidence": 94.21134185791016
            }
          ],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 24208,
        "Label": {
          "Name": "Buffalo",
          "Confidence": 53.90180206298828,
          "Instances": [],
          "Parents": [
            {
              "Name": "Wildlife"
            },
            {
              "Name": "Mammal"
            },
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 24208,
        "Label": {
          "Name": "Field",
          "Confidence": 55.09822463989258,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 24208,
        "Label": {
          "Name": "Halo",
          "Confidence": 50.26266098022461,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 24208,
        "Label": {
          "Name": "Human",
          "Confidence": 81.83162689208984,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 24208,
        "Label": {
          "Name": "Mammal",
          "Confidence": 53.90180206298828,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 24208,
        "Label": {
          "Name": "Nature",
          "Confidence": 77.7964859008789,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 24208,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 82.08700561523438,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 24208,
        "Label": {
          "Name": "Person",
          "Confidence": 81.83162689208984,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.024391841143369675,
                "Height": 0.11926209926605225,
                "Left": 0.48402342200279236,
                "Top": 0.49832069873809814
              },
              "Confidence": 56.341796875
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 24208,
        "Label": {
          "Name": "Transportation",
          "Confidence": 57.11648941040039,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 24208,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 56.96347427368164,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 24208,
        "Label": {
          "Name": "Wildlife",
          "Confidence": 53.90180206298828,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 24708,
        "Label": {
          "Name": "Aircraft",
          "Confidence": 84.43899536132812,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 24708,
        "Label": {
          "Name": "Animal",
          "Confidence": 59.654266357421875,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 24708,
        "Label": {
          "Name": "Buffalo",
          "Confidence": 51.90795135498047,
          "Instances": [],
          "Parents": [
            {
              "Name": "Wildlife"
            },
            {
              "Name": "Mammal"
            },
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 24708,
        "Label": {
          "Name": "Field",
          "Confidence": 51.972896575927734,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 24708,
        "Label": {
          "Name": "Helicopter",
          "Confidence": 83.83644104003906,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.5605021715164185,
                "Height": 0.27073967456817627,
                "Left": 0.2714191973209381,
                "Top": 0.28824272751808167
              },
              "Confidence": 95.1063003540039
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 24708,
        "Label": {
          "Name": "Human",
          "Confidence": 93.49730682373047,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 24708,
        "Label": {
          "Name": "Mammal",
          "Confidence": 51.90795135498047,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 24708,
        "Label": {
          "Name": "Mountain",
          "Confidence": 70.75262451171875,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 24708,
        "Label": {
          "Name": "Nature",
          "Confidence": 84.9572982788086,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 24708,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 86.68535614013672,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 24708,
        "Label": {
          "Name": "Person",
          "Confidence": 93.49730682373047,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.009762692265212536,
                "Height": 0.05616641417145729,
                "Left": 0.39018625020980835,
                "Top": 0.62147057056427
              },
              "Confidence": 97.73148345947266
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 24708,
        "Label": {
          "Name": "Transportation",
          "Confidence": 86.17144775390625,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 24708,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 86.12171173095703,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 24708,
        "Label": {
          "Name": "Wildlife",
          "Confidence": 51.90795135498047,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 25208,
        "Label": {
          "Name": "Aircraft",
          "Confidence": 97.23321533203125,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 25208,
        "Label": {
          "Name": "Animal",
          "Confidence": 51.591453552246094,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 25208,
        "Label": {
          "Name": "Buffalo",
          "Confidence": 51.591453552246094,
          "Instances": [],
          "Parents": [
            {
              "Name": "Wildlife"
            },
            {
              "Name": "Mammal"
            },
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 25208,
        "Label": {
          "Name": "Building",
          "Confidence": 55.52961349487305,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 25208,
        "Label": {
          "Name": "Call of Duty",
          "Confidence": 53.09915542602539,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 25208,
        "Label": {
          "Name": "Fire",
          "Confidence": 51.95728302001953,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 25208,
        "Label": {
          "Name": "Helicopter",
          "Confidence": 97.23321533203125,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.5630744695663452,
                "Height": 0.2751074731349945,
                "Left": 0.25024423003196716,
                "Top": 0.2784253656864166
              },
              "Confidence": 97.58525848388672
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 25208,
        "Label": {
          "Name": "Human",
          "Confidence": 97.44889831542969,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 25208,
        "Label": {
          "Name": "Mammal",
          "Confidence": 51.591453552246094,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 25208,
        "Label": {
          "Name": "Mountain",
          "Confidence": 68.3657455444336,
          "Instances": [],
          "Parents": [
            {
              "Name": "Outdoors"
            },
            {
              "Name": "Nature"
            }
          ]
        }
      },
      {
        "Timestamp": 25208,
        "Label": {
          "Name": "Nature",
          "Confidence": 69.93085479736328,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 25208,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 71.60211944580078,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 25208,
        "Label": {
          "Name": "Person",
          "Confidence": 97.44889831542969,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.012324142269790173,
                "Height": 0.05608181282877922,
                "Left": 0.3909545838832855,
                "Top": 0.6197431087493896
              },
              "Confidence": 97.6529541015625
            },
            {
              "BoundingBox": {
                "Width": 0.043761350214481354,
                "Height": 0.10656136274337769,
                "Left": 0.5506229400634766,
                "Top": 0.37804675102233887
              },
              "Confidence": 53.77814865112305
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 25208,
        "Label": {
          "Name": "Transportation",
          "Confidence": 97.23321533203125,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 25208,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 97.23321533203125,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 25208,
        "Label": {
          "Name": "Wildlife",
          "Confidence": 51.591453552246094,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 25708,
        "Label": {
          "Name": "Aircraft",
          "Confidence": 97.70820617675781,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 25708,
        "Label": {
          "Name": "Call of Duty",
          "Confidence": 52.49823760986328,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 25708,
        "Label": {
          "Name": "Halo",
          "Confidence": 60.84963607788086,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 25708,
        "Label": {
          "Name": "Helicopter",
          "Confidence": 97.70820617675781,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.5449124574661255,
                "Height": 0.2707534730434418,
                "Left": 0.24020440876483917,
                "Top": 0.28456273674964905
              },
              "Confidence": 98.27690887451172
            },
            {
              "BoundingBox": {
                "Width": 0.24675960838794708,
                "Height": 0.27061742544174194,
                "Left": 0.52481609582901,
                "Top": 0.2706634998321533
              },
              "Confidence": 91.36699676513672
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 25708,
        "Label": {
          "Name": "Human",
          "Confidence": 96.4866943359375,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 25708,
        "Label": {
          "Name": "Person",
          "Confidence": 96.4866943359375,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.010857653804123402,
                "Height": 0.056141410022974014,
                "Left": 0.39407140016555786,
                "Top": 0.6176159977912903
              },
              "Confidence": 96.53837585449219
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 25708,
        "Label": {
          "Name": "Transportation",
          "Confidence": 97.70820617675781,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 25708,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 97.70820617675781,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 26208,
        "Label": {
          "Name": "Aircraft",
          "Confidence": 96.6788101196289,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 26208,
        "Label": {
          "Name": "Halo",
          "Confidence": 77.08109283447266,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 26208,
        "Label": {
          "Name": "Helicopter",
          "Confidence": 96.6788101196289,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.5501128435134888,
                "Height": 0.2568364441394806,
                "Left": 0.23113539814949036,
                "Top": 0.289694607257843
              },
              "Confidence": 96.08126068115234
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 26208,
        "Label": {
          "Name": "Human",
          "Confidence": 95.73558044433594,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 26208,
        "Label": {
          "Name": "Machine",
          "Confidence": 74.0087661743164,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 26208,
        "Label": {
          "Name": "Person",
          "Confidence": 95.73558044433594,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.012274551205337048,
                "Height": 0.05606164038181305,
                "Left": 0.39743342995643616,
                "Top": 0.6160041093826294
              },
              "Confidence": 95.1613998413086
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 26208,
        "Label": {
          "Name": "Transportation",
          "Confidence": 96.6788101196289,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 26208,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 96.6788101196289,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 26208,
        "Label": {
          "Name": "Wheel",
          "Confidence": 69.05625915527344,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.061606504023075104,
                "Height": 0.1167161762714386,
                "Left": 0.6022433042526245,
                "Top": 0.4071453809738159
              },
              "Confidence": 92.57649993896484
            }
          ],
          "Parents": [
            {
              "Name": "Machine"
            }
          ]
        }
      },
      {
        "Timestamp": 26708,
        "Label": {
          "Name": "Aircraft",
          "Confidence": 96.83893585205078,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 26708,
        "Label": {
          "Name": "Halo",
          "Confidence": 70.50489044189453,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 26708,
        "Label": {
          "Name": "Helicopter",
          "Confidence": 96.83893585205078,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.6043988466262817,
                "Height": 0.28078559041023254,
                "Left": 0.2137482464313507,
                "Top": 0.27453386783599854
              },
              "Confidence": 96.91931915283203
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 26708,
        "Label": {
          "Name": "Human",
          "Confidence": 96.67433166503906,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 26708,
        "Label": {
          "Name": "Machine",
          "Confidence": 65.0327377319336,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 26708,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 50.763301849365234,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 26708,
        "Label": {
          "Name": "Person",
          "Confidence": 96.67433166503906,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.010866927914321423,
                "Height": 0.05342288687825203,
                "Left": 0.40189146995544434,
                "Top": 0.6148157715797424
              },
              "Confidence": 96.69945526123047
            },
            {
              "BoundingBox": {
                "Width": 0.015957355499267578,
                "Height": 0.023988766595721245,
                "Left": 0.7164393067359924,
                "Top": 0.33642175793647766
              },
              "Confidence": 47.816429138183594
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 26708,
        "Label": {
          "Name": "Transportation",
          "Confidence": 96.83893585205078,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 26708,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 96.83893585205078,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 26708,
        "Label": {
          "Name": "Wheel",
          "Confidence": 65.0327377319336,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.05744190141558647,
                "Height": 0.11368264257907867,
                "Left": 0.5968576669692993,
                "Top": 0.4075690507888794
              },
              "Confidence": 65.74251556396484
            }
          ],
          "Parents": [
            {
              "Name": "Machine"
            }
          ]
        }
      },
      {
        "Timestamp": 27208,
        "Label": {
          "Name": "Aircraft",
          "Confidence": 95.69944763183594,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 27208,
        "Label": {
          "Name": "Halo",
          "Confidence": 62.83424758911133,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 27208,
        "Label": {
          "Name": "Helicopter",
          "Confidence": 95.69944763183594,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.5696852803230286,
                "Height": 0.251011461019516,
                "Left": 0.21214644610881805,
                "Top": 0.3006652295589447
              },
              "Confidence": 97.34930419921875
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 27208,
        "Label": {
          "Name": "Human",
          "Confidence": 97.20391082763672,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 27208,
        "Label": {
          "Name": "Person",
          "Confidence": 97.20391082763672,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.010917949490249157,
                "Height": 0.05535651370882988,
                "Left": 0.4054221510887146,
                "Top": 0.6104893684387207
              },
              "Confidence": 98.10993957519531
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 27208,
        "Label": {
          "Name": "Transportation",
          "Confidence": 95.69944763183594,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 27208,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 95.69944763183594,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 27708,
        "Label": {
          "Name": "Aircraft",
          "Confidence": 88.25008392333984,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 27708,
        "Label": {
          "Name": "Automobile",
          "Confidence": 60.94136428833008,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 27708,
        "Label": {
          "Name": "Car",
          "Confidence": 60.94136428833008,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.19429798424243927,
                "Height": 0.18094533681869507,
                "Left": 0.5197519659996033,
                "Top": 0.3473108112812042
              },
              "Confidence": 55.88700485229492
            }
          ],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 27708,
        "Label": {
          "Name": "Halo",
          "Confidence": 64.60421752929688,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 27708,
        "Label": {
          "Name": "Helicopter",
          "Confidence": 88.25008392333984,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.5797290802001953,
                "Height": 0.2544785439968109,
                "Left": 0.2143198549747467,
                "Top": 0.2937893867492676
              },
              "Confidence": 89.403076171875
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 27708,
        "Label": {
          "Name": "Human",
          "Confidence": 95.42916870117188,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 27708,
        "Label": {
          "Name": "Machine",
          "Confidence": 61.545005798339844,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 27708,
        "Label": {
          "Name": "Person",
          "Confidence": 95.42916870117188,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.010965252295136452,
                "Height": 0.0538703054189682,
                "Left": 0.41072559356689453,
                "Top": 0.6088823676109314
              },
              "Confidence": 94.92058563232422
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 27708,
        "Label": {
          "Name": "Transportation",
          "Confidence": 90.83324432373047,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 27708,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 90.83324432373047,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 27708,
        "Label": {
          "Name": "Wheel",
          "Confidence": 61.545005798339844,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.07431039959192276,
                "Height": 0.12805481255054474,
                "Left": 0.5817270278930664,
                "Top": 0.3944661319255829
              },
              "Confidence": 58.918941497802734
            }
          ],
          "Parents": [
            {
              "Name": "Machine"
            }
          ]
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Aircraft",
          "Confidence": 81.76043701171875,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Airplane",
          "Confidence": 61.748260498046875,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.49498099088668823,
                "Height": 0.25284406542778015,
                "Left": 0.2474866807460785,
                "Top": 0.29667431116104126
              },
              "Confidence": 67.01162719726562
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Animal",
          "Confidence": 52.03935623168945,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Automobile",
          "Confidence": 73.59333801269531,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Buffalo",
          "Confidence": 52.03935623168945,
          "Instances": [],
          "Parents": [
            {
              "Name": "Wildlife"
            },
            {
              "Name": "Mammal"
            },
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Car",
          "Confidence": 73.59333801269531,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.3988109529018402,
                "Height": 0.21700653433799744,
                "Left": 0.29880475997924805,
                "Top": 0.3337307274341583
              },
              "Confidence": 88.71766662597656
            }
          ],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Display",
          "Confidence": 52.67648696899414,
          "Instances": [],
          "Parents": [
            {
              "Name": "Screen"
            },
            {
              "Name": "Electronics"
            }
          ]
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Electronics",
          "Confidence": 54.1254997253418,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Grand Theft Auto",
          "Confidence": 51.149757385253906,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Halo",
          "Confidence": 57.60038375854492,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Helicopter",
          "Confidence": 81.76043701171875,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.5578120350837708,
                "Height": 0.26538509130477905,
                "Left": 0.22146017849445343,
                "Top": 0.2892603874206543
              },
              "Confidence": 75.60316467285156
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Human",
          "Confidence": 94.97106170654297,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Machine",
          "Confidence": 87.15800476074219,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Mammal",
          "Confidence": 52.03935623168945,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Monitor",
          "Confidence": 52.67648696899414,
          "Instances": [],
          "Parents": [
            {
              "Name": "Screen"
            },
            {
              "Name": "Electronics"
            }
          ]
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Nature",
          "Confidence": 67.00303649902344,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 66.69404602050781,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Person",
          "Confidence": 94.97106170654297,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.010631847195327282,
                "Height": 0.05517578125,
                "Left": 0.41731730103492737,
                "Top": 0.6071431636810303
              },
              "Confidence": 94.31324005126953
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Screen",
          "Confidence": 54.1254997253418,
          "Instances": [],
          "Parents": [
            {
              "Name": "Electronics"
            }
          ]
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Tire",
          "Confidence": 50.618186950683594,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Transportation",
          "Confidence": 89.7086181640625,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 89.7086181640625,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Wheel",
          "Confidence": 87.15800476074219,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.06994657218456268,
                "Height": 0.12566621601581573,
                "Left": 0.5784860849380493,
                "Top": 0.39863699674606323
              },
              "Confidence": 95.86515808105469
            }
          ],
          "Parents": [
            {
              "Name": "Machine"
            }
          ]
        }
      },
      {
        "Timestamp": 28208,
        "Label": {
          "Name": "Wildlife",
          "Confidence": 52.03935623168945,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 28708,
        "Label": {
          "Name": "Aircraft",
          "Confidence": 89.68990325927734,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 28708,
        "Label": {
          "Name": "Airplane",
          "Confidence": 61.982093811035156,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.510558009147644,
                "Height": 0.2621118426322937,
                "Left": 0.23919332027435303,
                "Top": 0.28755295276641846
              },
              "Confidence": 69.58512878417969
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 28708,
        "Label": {
          "Name": "Animal",
          "Confidence": 50.940025329589844,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 28708,
        "Label": {
          "Name": "Automobile",
          "Confidence": 51.27593231201172,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 28708,
        "Label": {
          "Name": "Buffalo",
          "Confidence": 50.940025329589844,
          "Instances": [],
          "Parents": [
            {
              "Name": "Wildlife"
            },
            {
              "Name": "Mammal"
            },
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 28708,
        "Label": {
          "Name": "Car",
          "Confidence": 51.27593231201172,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 28708,
        "Label": {
          "Name": "Halo",
          "Confidence": 63.48183059692383,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 28708,
        "Label": {
          "Name": "Helicopter",
          "Confidence": 89.68990325927734,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.5636493563652039,
                "Height": 0.27249017357826233,
                "Left": 0.20868989825248718,
                "Top": 0.2789802551269531
              },
              "Confidence": 93.0632095336914
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 28708,
        "Label": {
          "Name": "Human",
          "Confidence": 96.46312713623047,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 28708,
        "Label": {
          "Name": "Machine",
          "Confidence": 90.08097839355469,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 28708,
        "Label": {
          "Name": "Mammal",
          "Confidence": 50.940025329589844,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 28708,
        "Label": {
          "Name": "Nature",
          "Confidence": 58.76483154296875,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 28708,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 58.32499694824219,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 28708,
        "Label": {
          "Name": "Person",
          "Confidence": 96.46312713623047,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.01058340072631836,
                "Height": 0.054539237171411514,
                "Left": 0.4232760965824127,
                "Top": 0.6071580052375793
              },
              "Confidence": 97.04558563232422
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 28708,
        "Label": {
          "Name": "Transportation",
          "Confidence": 92.27306365966797,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 28708,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 92.27306365966797,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 28708,
        "Label": {
          "Name": "Wheel",
          "Confidence": 90.08097839355469,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.04670076444745064,
                "Height": 0.10249777883291245,
                "Left": 0.5834845304489136,
                "Top": 0.4096566438674927
              },
              "Confidence": 88.60578918457031
            }
          ],
          "Parents": [
            {
              "Name": "Machine"
            }
          ]
        }
      },
      {
        "Timestamp": 28708,
        "Label": {
          "Name": "Wildlife",
          "Confidence": 50.940025329589844,
          "Instances": [],
          "Parents": [
            {
              "Name": "Animal"
            }
          ]
        }
      },
      {
        "Timestamp": 29208,
        "Label": {
          "Name": "Aircraft",
          "Confidence": 94.30525970458984,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 29208,
        "Label": {
          "Name": "Halo",
          "Confidence": 74.29656219482422,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 29208,
        "Label": {
          "Name": "Helicopter",
          "Confidence": 94.30525970458984,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.555783748626709,
                "Height": 0.26059773564338684,
                "Left": 0.20665845274925232,
                "Top": 0.2890971004962921
              },
              "Confidence": 93.39720153808594
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 29208,
        "Label": {
          "Name": "Human",
          "Confidence": 96.65768432617188,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 29208,
        "Label": {
          "Name": "Machine",
          "Confidence": 86.3484878540039,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 29208,
        "Label": {
          "Name": "Person",
          "Confidence": 96.65768432617188,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.010840987786650658,
                "Height": 0.0528225377202034,
                "Left": 0.4270806908607483,
                "Top": 0.6073635220527649
              },
              "Confidence": 96.82080078125
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 29208,
        "Label": {
          "Name": "Transportation",
          "Confidence": 94.30525970458984,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 29208,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 94.30525970458984,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 29208,
        "Label": {
          "Name": "Wheel",
          "Confidence": 86.3484878540039,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.06057014316320419,
                "Height": 0.1161586344242096,
                "Left": 0.5753492712974548,
                "Top": 0.4060363471508026
              },
              "Confidence": 88.8357925415039
            }
          ],
          "Parents": [
            {
              "Name": "Machine"
            }
          ]
        }
      },
      {
        "Timestamp": 29708,
        "Label": {
          "Name": "Aircraft",
          "Confidence": 97.2791748046875,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 29708,
        "Label": {
          "Name": "Halo",
          "Confidence": 71.43006896972656,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 29708,
        "Label": {
          "Name": "Helicopter",
          "Confidence": 97.2791748046875,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.5475466847419739,
                "Height": 0.26712897419929504,
                "Left": 0.21123313903808594,
                "Top": 0.28876182436943054
              },
              "Confidence": 98.34130859375
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 29708,
        "Label": {
          "Name": "Human",
          "Confidence": 95.00312805175781,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 29708,
        "Label": {
          "Name": "Machine",
          "Confidence": 74.67780303955078,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 29708,
        "Label": {
          "Name": "Nature",
          "Confidence": 50.29410934448242,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 29708,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 53.16392517089844,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 29708,
        "Label": {
          "Name": "Person",
          "Confidence": 95.00312805175781,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.01074762362986803,
                "Height": 0.05543908104300499,
                "Left": 0.4321210980415344,
                "Top": 0.606657862663269
              },
              "Confidence": 95.76786041259766
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 29708,
        "Label": {
          "Name": "Transportation",
          "Confidence": 97.2791748046875,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 29708,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 97.2791748046875,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 29708,
        "Label": {
          "Name": "Wheel",
          "Confidence": 74.67780303955078,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.043074894696474075,
                "Height": 0.09249674528837204,
                "Left": 0.5756767988204956,
                "Top": 0.42002496123313904
              },
              "Confidence": 76.43791961669922
            }
          ],
          "Parents": [
            {
              "Name": "Machine"
            }
          ]
        }
      },
      {
        "Timestamp": 30208,
        "Label": {
          "Name": "Aircraft",
          "Confidence": 97.96316528320312,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 30208,
        "Label": {
          "Name": "Animal",
          "Confidence": 54.995521545410156,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 30208,
        "Label": {
          "Name": "Halo",
          "Confidence": 59.309200286865234,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 30208,
        "Label": {
          "Name": "Helicopter",
          "Confidence": 97.96316528320312,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.5901221036911011,
                "Height": 0.2839980125427246,
                "Left": 0.18562893569469452,
                "Top": 0.26690873503685
              },
              "Confidence": 97.89299774169922
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 30208,
        "Label": {
          "Name": "Human",
          "Confidence": 91.6050033569336,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 30208,
        "Label": {
          "Name": "Machine",
          "Confidence": 59.124446868896484,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 30208,
        "Label": {
          "Name": "Nature",
          "Confidence": 50.46694564819336,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 30208,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 52.285369873046875,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 30208,
        "Label": {
          "Name": "Person",
          "Confidence": 91.6050033569336,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.011030483059585094,
                "Height": 0.052864667028188705,
                "Left": 0.4358651638031006,
                "Top": 0.606963038444519
              },
              "Confidence": 90.83240509033203
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 30208,
        "Label": {
          "Name": "Transportation",
          "Confidence": 97.96316528320312,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 30208,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 97.96316528320312,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 30208,
        "Label": {
          "Name": "Wheel",
          "Confidence": 59.124446868896484,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.043900392949581146,
                "Height": 0.09685075283050537,
                "Left": 0.5697196125984192,
                "Top": 0.4155527353286743
              },
              "Confidence": 55.104068756103516
            }
          ],
          "Parents": [
            {
              "Name": "Machine"
            }
          ]
        }
      },
      {
        "Timestamp": 30708,
        "Label": {
          "Name": "Aircraft",
          "Confidence": 97.05422973632812,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 30708,
        "Label": {
          "Name": "Airplane",
          "Confidence": 64.8062744140625,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.5710909962654114,
                "Height": 0.30897223949432373,
                "Left": 0.1960746943950653,
                "Top": 0.24838392436504364
              },
              "Confidence": 68.25455474853516
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 30708,
        "Label": {
          "Name": "Halo",
          "Confidence": 62.99946212768555,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 30708,
        "Label": {
          "Name": "Helicopter",
          "Confidence": 97.05422973632812,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.5380107164382935,
                "Height": 0.2844281494617462,
                "Left": 0.18398216366767883,
                "Top": 0.26806291937828064
              },
              "Confidence": 97.8009033203125
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 30708,
        "Label": {
          "Name": "Human",
          "Confidence": 89.7481460571289,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 30708,
        "Label": {
          "Name": "Machine",
          "Confidence": 58.211219787597656,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 30708,
        "Label": {
          "Name": "Nature",
          "Confidence": 56.96964645385742,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 30708,
        "Label": {
          "Name": "Outdoors",
          "Confidence": 59.695003509521484,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 30708,
        "Label": {
          "Name": "Person",
          "Confidence": 89.7481460571289,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.011423778720200062,
                "Height": 0.053367529064416885,
                "Left": 0.43607234954833984,
                "Top": 0.6059969663619995
              },
              "Confidence": 89.81936645507812
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 30708,
        "Label": {
          "Name": "Transportation",
          "Confidence": 97.05422973632812,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 30708,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 97.05422973632812,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 30708,
        "Label": {
          "Name": "Wheel",
          "Confidence": 58.211219787597656,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.0410950668156147,
                "Height": 0.09267764538526535,
                "Left": 0.562812864780426,
                "Top": 0.41942498087882996
              },
              "Confidence": 54.181365966796875
            }
          ],
          "Parents": [
            {
              "Name": "Machine"
            }
          ]
        }
      },
      {
        "Timestamp": 31208,
        "Label": {
          "Name": "Aircraft",
          "Confidence": 92.51487731933594,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 31208,
        "Label": {
          "Name": "Airplane",
          "Confidence": 71.33112335205078,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.5271028280258179,
                "Height": 0.2798384428024292,
                "Left": 0.1906702071428299,
                "Top": 0.2703501582145691
              },
              "Confidence": 78.96514129638672
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 31208,
        "Label": {
          "Name": "Halo",
          "Confidence": 75.25179290771484,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 31208,
        "Label": {
          "Name": "Helicopter",
          "Confidence": 92.51487731933594,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.5373550653457642,
                "Height": 0.2827158570289612,
                "Left": 0.1751820296049118,
                "Top": 0.2711881399154663
              },
              "Confidence": 93.9179916381836
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 31208,
        "Label": {
          "Name": "Human",
          "Confidence": 90.06491088867188,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 31208,
        "Label": {
          "Name": "Machine",
          "Confidence": 60.903472900390625,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 31208,
        "Label": {
          "Name": "Person",
          "Confidence": 90.06491088867188,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.011524677276611328,
                "Height": 0.052142757922410965,
                "Left": 0.429252564907074,
                "Top": 0.6062430143356323
              },
              "Confidence": 88.44473266601562
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 31208,
        "Label": {
          "Name": "Transportation",
          "Confidence": 92.51487731933594,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 31208,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 92.51487731933594,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 31208,
        "Label": {
          "Name": "Wheel",
          "Confidence": 55.349613189697266,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.0446198470890522,
                "Height": 0.09620191901922226,
                "Left": 0.5445001721382141,
                "Top": 0.41791826486587524
              },
              "Confidence": 73.71791076660156
            }
          ],
          "Parents": [
            {
              "Name": "Machine"
            }
          ]
        }
      },
      {
        "Timestamp": 31708,
        "Label": {
          "Name": "Aircraft",
          "Confidence": 87.8853759765625,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 31708,
        "Label": {
          "Name": "Airplane",
          "Confidence": 52.050315856933594,
          "Instances": [],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 31708,
        "Label": {
          "Name": "Halo",
          "Confidence": 75.97154235839844,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 31708,
        "Label": {
          "Name": "Helicopter",
          "Confidence": 87.8853759765625,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.5633003115653992,
                "Height": 0.279633492231369,
                "Left": 0.14097563922405243,
                "Top": 0.289495050907135
              },
              "Confidence": 82.91158294677734
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 31708,
        "Label": {
          "Name": "Human",
          "Confidence": 93.14812469482422,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 31708,
        "Label": {
          "Name": "Person",
          "Confidence": 93.14812469482422,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.012020016089081764,
                "Height": 0.05131293460726738,
                "Left": 0.4182228446006775,
                "Top": 0.6062634587287903
              },
              "Confidence": 95.29559326171875
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 31708,
        "Label": {
          "Name": "Transportation",
          "Confidence": 87.8853759765625,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 31708,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 87.8853759765625,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 32208,
        "Label": {
          "Name": "Aircraft",
          "Confidence": 92.51957702636719,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 32208,
        "Label": {
          "Name": "Call of Duty",
          "Confidence": 50.41701889038086,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 32208,
        "Label": {
          "Name": "Halo",
          "Confidence": 84.4688720703125,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 32208,
        "Label": {
          "Name": "Helicopter",
          "Confidence": 92.51957702636719,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.536361575126648,
                "Height": 0.2611531615257263,
                "Left": 0.13236799836158752,
                "Top": 0.29939019680023193
              },
              "Confidence": 97.15670776367188
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 32208,
        "Label": {
          "Name": "Human",
          "Confidence": 90.37425994873047,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 32208,
        "Label": {
          "Name": "Machine",
          "Confidence": 57.26253890991211,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 32208,
        "Label": {
          "Name": "Person",
          "Confidence": 90.37425994873047,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.012553500942885876,
                "Height": 0.053251054137945175,
                "Left": 0.4084561765193939,
                "Top": 0.6049476861953735
              },
              "Confidence": 91.24392700195312
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 32208,
        "Label": {
          "Name": "Transportation",
          "Confidence": 92.51957702636719,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 32208,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 92.51957702636719,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 32208,
        "Label": {
          "Name": "Wheel",
          "Confidence": 51.708675384521484,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.04029903560876846,
                "Height": 0.09674029797315598,
                "Left": 0.5097330212593079,
                "Top": 0.413614958524704
              },
              "Confidence": 57.3874397277832
            }
          ],
          "Parents": [
            {
              "Name": "Machine"
            }
          ]
        }
      },
      {
        "Timestamp": 32708,
        "Label": {
          "Name": "Aircraft",
          "Confidence": 72.38507080078125,
          "Instances": [],
          "Parents": [
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 32708,
        "Label": {
          "Name": "Airplane",
          "Confidence": 50.79710006713867,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.5098088979721069,
                "Height": 0.26344001293182373,
                "Left": 0.13162930309772491,
                "Top": 0.2934255301952362
              },
              "Confidence": 74.51426696777344
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 32708,
        "Label": {
          "Name": "Halo",
          "Confidence": 77.35392761230469,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 32708,
        "Label": {
          "Name": "Helicopter",
          "Confidence": 72.38507080078125,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.5623247027397156,
                "Height": 0.269689679145813,
                "Left": 0.10487306118011475,
                "Top": 0.2921271324157715
              },
              "Confidence": 87.85942840576172
            }
          ],
          "Parents": [
            {
              "Name": "Aircraft"
            },
            {
              "Name": "Vehicle"
            },
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 32708,
        "Label": {
          "Name": "Human",
          "Confidence": 68.14019775390625,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 32708,
        "Label": {
          "Name": "Machine",
          "Confidence": 68.2879409790039,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 32708,
        "Label": {
          "Name": "Person",
          "Confidence": 68.14019775390625,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.011793804354965687,
                "Height": 0.05268995463848114,
                "Left": 0.4018447995185852,
                "Top": 0.6033631563186646
              },
              "Confidence": 82.77703857421875
            }
          ],
          "Parents": []
        }
      },
      {
        "Timestamp": 32708,
        "Label": {
          "Name": "Transportation",
          "Confidence": 79.66175079345703,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 32708,
        "Label": {
          "Name": "Vehicle",
          "Confidence": 79.66175079345703,
          "Instances": [],
          "Parents": [
            {
              "Name": "Transportation"
            }
          ]
        }
      },
      {
        "Timestamp": 32708,
        "Label": {
          "Name": "Wheel",
          "Confidence": 63.3909912109375,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.04145460203289986,
                "Height": 0.09731157124042511,
                "Left": 0.4924408495426178,
                "Top": 0.4120747745037079
              },
              "Confidence": 85.9442138671875
            }
          ],
          "Parents": [
            {
              "Name": "Machine"
            }
          ]
        }
      },
      {
        "Timestamp": 33208,
        "Label": {
          "Name": "Alphabet",
          "Confidence": 55.025306701660156,
          "Instances": [],
          "Parents": [
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 33208,
        "Label": {
          "Name": "Business Card",
          "Confidence": 56.07257843017578,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.9010146856307983,
                "Height": 0.8186577558517456,
                "Left": 0.05202994495630264,
                "Top": 0.09268133342266083
              },
              "Confidence": 69.83183288574219
            }
          ],
          "Parents": [
            {
              "Name": "Paper"
            },
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 33208,
        "Label": {
          "Name": "Logo",
          "Confidence": 69.26873016357422,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 33208,
        "Label": {
          "Name": "Paper",
          "Confidence": 56.07257843017578,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 33208,
        "Label": {
          "Name": "Symbol",
          "Confidence": 72.40637969970703,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 33208,
        "Label": {
          "Name": "Text",
          "Confidence": 79.33037567138672,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 33208,
        "Label": {
          "Name": "Trademark",
          "Confidence": 69.26873016357422,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 33708,
        "Label": {
          "Name": "Alphabet",
          "Confidence": 63.81346130371094,
          "Instances": [],
          "Parents": [
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 33708,
        "Label": {
          "Name": "Business Card",
          "Confidence": 69.81349182128906,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.901039719581604,
                "Height": 0.818668782711029,
                "Left": 0.05201520770788193,
                "Top": 0.09267963469028473
              },
              "Confidence": 69.8089828491211
            }
          ],
          "Parents": [
            {
              "Name": "Paper"
            },
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 33708,
        "Label": {
          "Name": "Cushion",
          "Confidence": 50.6279411315918,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 33708,
        "Label": {
          "Name": "Face",
          "Confidence": 58.91313552856445,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 33708,
        "Label": {
          "Name": "Logo",
          "Confidence": 86.22294616699219,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 33708,
        "Label": {
          "Name": "Paper",
          "Confidence": 69.81349182128906,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 33708,
        "Label": {
          "Name": "Pillow",
          "Confidence": 50.6279411315918,
          "Instances": [],
          "Parents": [
            {
              "Name": "Cushion"
            }
          ]
        }
      },
      {
        "Timestamp": 33708,
        "Label": {
          "Name": "Symbol",
          "Confidence": 86.22294616699219,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 33708,
        "Label": {
          "Name": "Text",
          "Confidence": 94.04936218261719,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 33708,
        "Label": {
          "Name": "Trademark",
          "Confidence": 86.22294616699219,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 33708,
        "Label": {
          "Name": "Word",
          "Confidence": 54.259552001953125,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 34208,
        "Label": {
          "Name": "Alphabet",
          "Confidence": 63.82659149169922,
          "Instances": [],
          "Parents": [
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 34208,
        "Label": {
          "Name": "Business Card",
          "Confidence": 69.8089828491211,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.901039719581604,
                "Height": 0.818668782711029,
                "Left": 0.05201520770788193,
                "Top": 0.09267963469028473
              },
              "Confidence": 69.8089828491211
            }
          ],
          "Parents": [
            {
              "Name": "Paper"
            },
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 34208,
        "Label": {
          "Name": "Cushion",
          "Confidence": 50.61012268066406,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 34208,
        "Label": {
          "Name": "Face",
          "Confidence": 58.91313552856445,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 34208,
        "Label": {
          "Name": "Logo",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 34208,
        "Label": {
          "Name": "Paper",
          "Confidence": 69.8089828491211,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 34208,
        "Label": {
          "Name": "Pillow",
          "Confidence": 50.61012268066406,
          "Instances": [],
          "Parents": [
            {
              "Name": "Cushion"
            }
          ]
        }
      },
      {
        "Timestamp": 34208,
        "Label": {
          "Name": "Symbol",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 34208,
        "Label": {
          "Name": "Text",
          "Confidence": 94.05162811279297,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 34208,
        "Label": {
          "Name": "Trademark",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 34208,
        "Label": {
          "Name": "Word",
          "Confidence": 54.259552001953125,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 34708,
        "Label": {
          "Name": "Alphabet",
          "Confidence": 63.82659149169922,
          "Instances": [],
          "Parents": [
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 34708,
        "Label": {
          "Name": "Business Card",
          "Confidence": 69.8089828491211,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.901039719581604,
                "Height": 0.818668782711029,
                "Left": 0.05201520770788193,
                "Top": 0.09267963469028473
              },
              "Confidence": 69.8089828491211
            }
          ],
          "Parents": [
            {
              "Name": "Paper"
            },
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 34708,
        "Label": {
          "Name": "Cushion",
          "Confidence": 50.61012268066406,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 34708,
        "Label": {
          "Name": "Face",
          "Confidence": 58.91313552856445,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 34708,
        "Label": {
          "Name": "Logo",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 34708,
        "Label": {
          "Name": "Paper",
          "Confidence": 69.8089828491211,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 34708,
        "Label": {
          "Name": "Pillow",
          "Confidence": 50.61012268066406,
          "Instances": [],
          "Parents": [
            {
              "Name": "Cushion"
            }
          ]
        }
      },
      {
        "Timestamp": 34708,
        "Label": {
          "Name": "Symbol",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 34708,
        "Label": {
          "Name": "Text",
          "Confidence": 94.05162811279297,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 34708,
        "Label": {
          "Name": "Trademark",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 34708,
        "Label": {
          "Name": "Word",
          "Confidence": 54.259552001953125,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 35208,
        "Label": {
          "Name": "Alphabet",
          "Confidence": 63.82659149169922,
          "Instances": [],
          "Parents": [
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 35208,
        "Label": {
          "Name": "Business Card",
          "Confidence": 69.8089828491211,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.901039719581604,
                "Height": 0.818668782711029,
                "Left": 0.05201520770788193,
                "Top": 0.09267963469028473
              },
              "Confidence": 69.8089828491211
            }
          ],
          "Parents": [
            {
              "Name": "Paper"
            },
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 35208,
        "Label": {
          "Name": "Cushion",
          "Confidence": 50.61012268066406,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 35208,
        "Label": {
          "Name": "Face",
          "Confidence": 58.91313552856445,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 35208,
        "Label": {
          "Name": "Logo",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 35208,
        "Label": {
          "Name": "Paper",
          "Confidence": 69.8089828491211,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 35208,
        "Label": {
          "Name": "Pillow",
          "Confidence": 50.61012268066406,
          "Instances": [],
          "Parents": [
            {
              "Name": "Cushion"
            }
          ]
        }
      },
      {
        "Timestamp": 35208,
        "Label": {
          "Name": "Symbol",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 35208,
        "Label": {
          "Name": "Text",
          "Confidence": 94.05162811279297,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 35208,
        "Label": {
          "Name": "Trademark",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 35208,
        "Label": {
          "Name": "Word",
          "Confidence": 54.259552001953125,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 35708,
        "Label": {
          "Name": "Alphabet",
          "Confidence": 63.82659149169922,
          "Instances": [],
          "Parents": [
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 35708,
        "Label": {
          "Name": "Business Card",
          "Confidence": 69.8089828491211,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.901039719581604,
                "Height": 0.818668782711029,
                "Left": 0.05201520770788193,
                "Top": 0.09267963469028473
              },
              "Confidence": 69.8089828491211
            }
          ],
          "Parents": [
            {
              "Name": "Paper"
            },
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 35708,
        "Label": {
          "Name": "Cushion",
          "Confidence": 50.61012268066406,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 35708,
        "Label": {
          "Name": "Face",
          "Confidence": 58.91313552856445,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 35708,
        "Label": {
          "Name": "Logo",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 35708,
        "Label": {
          "Name": "Paper",
          "Confidence": 69.8089828491211,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 35708,
        "Label": {
          "Name": "Pillow",
          "Confidence": 50.61012268066406,
          "Instances": [],
          "Parents": [
            {
              "Name": "Cushion"
            }
          ]
        }
      },
      {
        "Timestamp": 35708,
        "Label": {
          "Name": "Symbol",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 35708,
        "Label": {
          "Name": "Text",
          "Confidence": 94.05162811279297,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 35708,
        "Label": {
          "Name": "Trademark",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 35708,
        "Label": {
          "Name": "Word",
          "Confidence": 54.259552001953125,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 36208,
        "Label": {
          "Name": "Alphabet",
          "Confidence": 63.82659149169922,
          "Instances": [],
          "Parents": [
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 36208,
        "Label": {
          "Name": "Business Card",
          "Confidence": 69.8089828491211,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.901039719581604,
                "Height": 0.818668782711029,
                "Left": 0.05201520770788193,
                "Top": 0.09267963469028473
              },
              "Confidence": 69.8089828491211
            }
          ],
          "Parents": [
            {
              "Name": "Paper"
            },
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 36208,
        "Label": {
          "Name": "Cushion",
          "Confidence": 50.61012268066406,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 36208,
        "Label": {
          "Name": "Face",
          "Confidence": 58.91313552856445,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 36208,
        "Label": {
          "Name": "Logo",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 36208,
        "Label": {
          "Name": "Paper",
          "Confidence": 69.8089828491211,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 36208,
        "Label": {
          "Name": "Pillow",
          "Confidence": 50.61012268066406,
          "Instances": [],
          "Parents": [
            {
              "Name": "Cushion"
            }
          ]
        }
      },
      {
        "Timestamp": 36208,
        "Label": {
          "Name": "Symbol",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 36208,
        "Label": {
          "Name": "Text",
          "Confidence": 94.05162811279297,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 36208,
        "Label": {
          "Name": "Trademark",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 36208,
        "Label": {
          "Name": "Word",
          "Confidence": 54.259552001953125,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 36708,
        "Label": {
          "Name": "Alphabet",
          "Confidence": 63.82659149169922,
          "Instances": [],
          "Parents": [
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 36708,
        "Label": {
          "Name": "Business Card",
          "Confidence": 69.8089828491211,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.901039719581604,
                "Height": 0.818668782711029,
                "Left": 0.05201520770788193,
                "Top": 0.09267963469028473
              },
              "Confidence": 69.8089828491211
            }
          ],
          "Parents": [
            {
              "Name": "Paper"
            },
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 36708,
        "Label": {
          "Name": "Cushion",
          "Confidence": 50.61012268066406,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 36708,
        "Label": {
          "Name": "Face",
          "Confidence": 58.91313552856445,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 36708,
        "Label": {
          "Name": "Logo",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 36708,
        "Label": {
          "Name": "Paper",
          "Confidence": 69.8089828491211,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 36708,
        "Label": {
          "Name": "Pillow",
          "Confidence": 50.61012268066406,
          "Instances": [],
          "Parents": [
            {
              "Name": "Cushion"
            }
          ]
        }
      },
      {
        "Timestamp": 36708,
        "Label": {
          "Name": "Symbol",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 36708,
        "Label": {
          "Name": "Text",
          "Confidence": 94.05162811279297,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 36708,
        "Label": {
          "Name": "Trademark",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 36708,
        "Label": {
          "Name": "Word",
          "Confidence": 54.259552001953125,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 37208,
        "Label": {
          "Name": "Alphabet",
          "Confidence": 63.82659149169922,
          "Instances": [],
          "Parents": [
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 37208,
        "Label": {
          "Name": "Business Card",
          "Confidence": 69.8089828491211,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.901039719581604,
                "Height": 0.818668782711029,
                "Left": 0.05201520770788193,
                "Top": 0.09267963469028473
              },
              "Confidence": 69.8089828491211
            }
          ],
          "Parents": [
            {
              "Name": "Paper"
            },
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 37208,
        "Label": {
          "Name": "Cushion",
          "Confidence": 50.61012268066406,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 37208,
        "Label": {
          "Name": "Face",
          "Confidence": 58.91313552856445,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 37208,
        "Label": {
          "Name": "Logo",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 37208,
        "Label": {
          "Name": "Paper",
          "Confidence": 69.8089828491211,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 37208,
        "Label": {
          "Name": "Pillow",
          "Confidence": 50.61012268066406,
          "Instances": [],
          "Parents": [
            {
              "Name": "Cushion"
            }
          ]
        }
      },
      {
        "Timestamp": 37208,
        "Label": {
          "Name": "Symbol",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 37208,
        "Label": {
          "Name": "Text",
          "Confidence": 94.05162811279297,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 37208,
        "Label": {
          "Name": "Trademark",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 37208,
        "Label": {
          "Name": "Word",
          "Confidence": 54.259552001953125,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 37708,
        "Label": {
          "Name": "Alphabet",
          "Confidence": 63.826595306396484,
          "Instances": [],
          "Parents": [
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 37708,
        "Label": {
          "Name": "Business Card",
          "Confidence": 69.8089828491211,
          "Instances": [
            {
              "BoundingBox": {
                "Width": 0.901039719581604,
                "Height": 0.818668782711029,
                "Left": 0.05201520770788193,
                "Top": 0.09267963469028473
              },
              "Confidence": 69.8089828491211
            }
          ],
          "Parents": [
            {
              "Name": "Paper"
            },
            {
              "Name": "Text"
            }
          ]
        }
      },
      {
        "Timestamp": 37708,
        "Label": {
          "Name": "Cushion",
          "Confidence": 50.6101188659668,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 37708,
        "Label": {
          "Name": "Face",
          "Confidence": 58.91313552856445,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 37708,
        "Label": {
          "Name": "Logo",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 37708,
        "Label": {
          "Name": "Paper",
          "Confidence": 69.8089828491211,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 37708,
        "Label": {
          "Name": "Pillow",
          "Confidence": 50.6101188659668,
          "Instances": [],
          "Parents": [
            {
              "Name": "Cushion"
            }
          ]
        }
      },
      {
        "Timestamp": 37708,
        "Label": {
          "Name": "Symbol",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 37708,
        "Label": {
          "Name": "Text",
          "Confidence": 94.05162811279297,
          "Instances": [],
          "Parents": []
        }
      },
      {
        "Timestamp": 37708,
        "Label": {
          "Name": "Trademark",
          "Confidence": 86.21015930175781,
          "Instances": [],
          "Parents": [
            {
              "Name": "Symbol"
            }
          ]
        }
      },
      {
        "Timestamp": 37708,
        "Label": {
          "Name": "Word",
          "Confidence": 54.259552001953125,
          "Instances": [],
          "Parents": []
        }
      }
    ],
    "LabelModelVersion": "2.0",
    "ResponseMetadata": {
      "RequestId": "e0bacd65-4d14-4265-90c5-7b58fc86ef20",
      "HTTPStatusCode": 200,
      "HTTPHeaders": {
        "x-amzn-requestid": "e0bacd65-4d14-4265-90c5-7b58fc86ef20",
        "content-type": "application/x-amz-json-1.1",
        "content-length": "114188",
        "date": "Wed, 02 Nov 2022 15:00:15 GMT"
      },
      "RetryAttempts": 0
    }
  }
}

# %%
labels = event["LabelDetectionData"]["Labels"]

# %%
def create_node(node):
    print(f"Simulating creation of node: {node['Name']}")
    
def create_edge(node1, node2, edge_type):
    print(f"Simulating creation of {edge_type} edge between {node1['Name']} and {node2['Name']}")

# %%
nodes_by_timestamp = {} # key will be timestamp, value will be list of Labels

for label in labels:
#     print(label)
#     print(label["Timestamp"])
#     print(label["Label"])
    timestamp = label["Timestamp"]
    if not timestamp in nodes_by_timestamp.keys():
        nodes_by_timestamp[timestamp] = []
    nodes_by_timestamp[timestamp].append(label)

# %%
import itertools

key = "ThisIsADummyVideo.mp4"
video_node = {
    "Type": "Video",
    "Name": key
}

for timestamp in nodes_by_timestamp.keys():
    labels = [it["Label"] for it in nodes_by_timestamp[timestamp]]
    for label in labels:
        create_node(label)
        create_edge(label)
    for e1, e2 in itertools.combinations(labels, 2):
        create_edge(e1, e2, "APPEARS_WITH")
# Out:
# Simulating creation of node: Apparel
# Simulating creation of node: Arrow
# Simulating creation of node: Clothing
# Simulating creation of node: Face
# Simulating creation of node: Final Fantasy
# Simulating creation of node: Page
# Simulating creation of node: Symbol
# Simulating creation of node: Text
# Simulating creation of node: Texture
# Simulating creation of node: White
# Simulating creation of node: White Board
# Simulating creation of APPEARS_WITH edge between Apparel and Arrow
# Simulating creation of APPEARS_WITH edge between Apparel and Clothing
# Simulating creation of APPEARS_WITH edge between Apparel and Face
# Simulating creation of APPEARS_WITH edge between Apparel and Final Fantasy
# Simulating creation of APPEARS_WITH edge between Apparel and Page
# Simulating creation of APPEARS_WITH edge between Apparel and Symbol
# Simulating creation of APPEARS_WITH edge between Apparel and Text
# Simulating creation of APPEARS_WITH edge between Apparel and Texture
# ...

# %%
nodes_by_timestamp[35708]
# Out:
# [{'Timestamp': 35708,
#   'Label': {'Name': 'Alphabet',
#    'Confidence': 63.82659149169922,
#    'Instances': [],
#    'Parents': [{'Name': 'Text'}]}},
#  {'Timestamp': 35708,
#   'Label': {'Name': 'Business Card',
#    'Confidence': 69.8089828491211,
#    'Instances': [{'BoundingBox': {'Width': 0.901039719581604,
#       'Height': 0.818668782711029,
#       'Left': 0.05201520770788193,
#       'Top': 0.09267963469028473},
#      'Confidence': 69.8089828491211}],
#    'Parents': [{'Name': 'Paper'}, {'Name': 'Text'}]}},
#  {'Timestamp': 35708,
#   'Label': {'Name': 'Cushion',
#    'Confidence': 50.61012268066406,
#    'Instances': [],
#    'Parents': []}},
#  {'Timestamp': 35708,
#   'Label': {'Name': 'Face',
#    'Confidence': 58.91313552856445,
#    'Instances': [],
#    'Parents': []}},
#  {'Timestamp': 35708,
#   'Label': {'Name': 'Logo',
#    'Confidence': 86.21015930175781,
#    'Instances': [],
#    'Parents': [{'Name': 'Symbol'}]}},
#  {'Timestamp': 35708,
# ...

# %%
import itertools

list(itertools.combinations(["A", "B", "C", "D"], 2))
# Out:
# [('A', 'B'), ('A', 'C'), ('A', 'D'), ('B', 'C'), ('B', 'D'), ('C', 'D')]

# %%
import hashlib
import csv

class GraphLoadFiles:
    def __init__(self, source_name):
        self.source_name = source_name
        self.nodes = []
        self.edges = []
        self.nodes_by_timestamp = {} # key will be timestamp, value will be list of Labels

    def create_node(self, node):
        print(f"Creating node: {node['Name']}")
        node["id"] = self.get_node_id(node)
        
        node_dict = {
            ":ID": self.get_node_id(node),
            ":Label": node["Name"],
            "confidence:Float": node["Confidence"]
        }
        self.nodes.append(node_dict)
        

    def create_edge(self, node1, node2, edge_type):
        node1_id = self.get_node_id(node1)
        node2_id = self.get_node_id(node2)
        edge = {
            ":ID": self.get_edge_id(node1, node2, edge_type),
            ":START_ID": self.get_node_id(node1),
            ":END_ID": self.get_node_id(node2),
            ":TYPE": edge_type
        } 
        self.edges.append(edge)
        print(f"Simulating creation of {edge_type} edge between {node1['Name']} and {node2['Name']}")

    def get_node_id(self, node):
        node_name = node["Name"]
        m = hashlib.new('md5')
        m.update(node_name.encode())
        node_id = m.hexdigest()
        return node_id
    
    def get_edge_id(self, node1, node2, edge_type):
        estring = f"{node1['Name']}-{edge_type}-{node2['Name']}"
        m = hashlib.new('md5')
        m.update(estring.encode())
        edge_id = m.hexdigest()
        return edge_id

    def sort_labels_by_timestamp(self, labels):
        for label in labels:
            timestamp = label["Timestamp"]
            if not timestamp in self.nodes_by_timestamp.keys():
                self.nodes_by_timestamp[timestamp] = []
            self.nodes_by_timestamp[timestamp].append(label)
        return self.nodes_by_timestamp
    
    def create_nodes_and_edges(self, root_node):
        for timestamp in self.nodes_by_timestamp.keys():
            labels = [it["Label"] for it in self.nodes_by_timestamp[timestamp]]
            for label in labels:
                self.create_node(label)
                self.create_edge(label, video_node, "APPEARS_IN")
            for e1, e2 in itertools.combinations(labels, 2):
                self.create_edge(e1, e2, "APPEARS_WITH")
                
    def write_nodes(self):
        with open(f"{self.source_name}-nodes.csv", "w") as output_file:
            dict_writer = csv.DictWriter(output_file, self.nodes[0].keys())
            dict_writer.writeheader()
            dict_writer.writerows(self.nodes)
            
    def write_edges(self):
        with open(f"{self.source_name}-edges.csv", "w") as output_file:
            dict_writer = csv.DictWriter(output_file, self.edges[0].keys())
            dict_writer.writeheader()
            dict_writer.writerows(self.edges)

# %%
gl = GraphLoadFiles(event["key"])

labels = event["LabelDetectionData"]["Labels"]
nodes_by_timestamp = gl.sort_labels_by_timestamp(labels)

# %%
video_node = {
    "Type": "Video",
    "Name": event["key"]
}

gl.create_nodes_and_edges(video_node)
# Out:
# Creating node: Apparel
# Simulating creation of APPEARS_IN edge between Apparel and TheAstronautOfficialTeaser34.mp4
# Creating node: Arrow
# Simulating creation of APPEARS_IN edge between Arrow and TheAstronautOfficialTeaser34.mp4
# Creating node: Clothing
# Simulating creation of APPEARS_IN edge between Clothing and TheAstronautOfficialTeaser34.mp4
# Creating node: Face
# Simulating creation of APPEARS_IN edge between Face and TheAstronautOfficialTeaser34.mp4
# Creating node: Final Fantasy
# Simulating creation of APPEARS_IN edge between Final Fantasy and TheAstronautOfficialTeaser34.mp4
# Creating node: Page
# Simulating creation of APPEARS_IN edge between Page and TheAstronautOfficialTeaser34.mp4
# Creating node: Symbol
# Simulating creation of APPEARS_IN edge between Symbol and TheAstronautOfficialTeaser34.mp4
# Creating node: Text
# Simulating creation of APPEARS_IN edge between Text and TheAstronautOfficialTeaser34.mp4
# Creating node: Texture
# ...

# %%
gl.nodes
# Out:
# [{':ID': 'fc43e587e3df077329b354a6ef05dd29',
#   ':Label': 'Apparel',
#   'confidence:Float': 55.38291549682617},
#  {':ID': '0f4e1aaabd074689b7d3ead824d1ee8e',
#   ':Label': 'Arrow',
#   'confidence:Float': 50.12788391113281},
#  {':ID': 'efe0bd2c212eceec598c42a15b8cd07f',
#   ':Label': 'Clothing',
#   'confidence:Float': 55.38291549682617},
#  {':ID': '8af5861002f3c157f9ba842bba10aa3f',
#   ':Label': 'Face',
#   'confidence:Float': 51.44035720825195},
#  {':ID': '636e48cb20aff512acac1609c23c0467',
#   ':Label': 'Final Fantasy',
#   'confidence:Float': 52.31382369995117},
#  {':ID': '193cfc9be3b995831c6af2fea6650e60',
#   ':Label': 'Page',
#   'confidence:Float': 53.37156295776367},
#  {':ID': '02c86eb2792f3262c21d030a87e19793',
#   ':Label': 'Symbol',
#   'confidence:Float': 50.12788391113281},
#  {':ID': '9dffbf69ffba8bc38bc4e01abf4b1675',
#   ':Label': 'Text',
#   'confidence:Float': 54.760807037353516},
#  {':ID': 'a3e8ae43188ae76d38f414b2bdb0077b',
#   ':Label': 'Texture',
# ...

# %%
gl.edges
# Out:
# [{':ID': '6e7ee4129d1b16d3c8519ff894cc2a74',
#   ':START_ID': 'fc43e587e3df077329b354a6ef05dd29',
#   ':END_ID': 'b0ef43f777a6d1e8f1186ab8d96d5ba2',
#   ':TYPE': 'APPEARS_IN'},
#  {':ID': '2293eb4c17ff40d1a4d34faa195e0f93',
#   ':START_ID': '0f4e1aaabd074689b7d3ead824d1ee8e',
#   ':END_ID': 'b0ef43f777a6d1e8f1186ab8d96d5ba2',
#   ':TYPE': 'APPEARS_IN'},
#  {':ID': '5fd54bfce14ca59f3a11ffcde7f66569',
#   ':START_ID': 'efe0bd2c212eceec598c42a15b8cd07f',
#   ':END_ID': 'b0ef43f777a6d1e8f1186ab8d96d5ba2',
#   ':TYPE': 'APPEARS_IN'},
#  {':ID': '82282142f4351097d28fd26c606cfc0e',
#   ':START_ID': '8af5861002f3c157f9ba842bba10aa3f',
#   ':END_ID': 'b0ef43f777a6d1e8f1186ab8d96d5ba2',
#   ':TYPE': 'APPEARS_IN'},
#  {':ID': '5aa906fe694f4291b9938c1b21d81db8',
#   ':START_ID': '636e48cb20aff512acac1609c23c0467',
#   ':END_ID': 'b0ef43f777a6d1e8f1186ab8d96d5ba2',
#   ':TYPE': 'APPEARS_IN'},
#  {':ID': '0d11a436c6b58474b4a1260872a32b17',
#   ':START_ID': '193cfc9be3b995831c6af2fea6650e60',
# ...

# %%
gl.write_nodes()

# %%
gl.write_edges()
